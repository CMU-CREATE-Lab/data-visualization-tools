# %%
# !wget https://data2.nhgis.org/extracts/97092/13/nhgis0013_csv.zip
# Out:
# --2017-04-10 16:55:31--  https://data2.nhgis.org/extracts/97092/13/nhgis0013_csv.zip
# Resolving data2.nhgis.org (data2.nhgis.org)... 128.101.163.216
# Connecting to data2.nhgis.org (data2.nhgis.org)|128.101.163.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4739822 (4.5M) [application/zip]
# Saving to: ‘nhgis0013_csv.zip’
#
# nhgis0013_csv.zip   100%[===================>]   4.52M  6.55MB/s    in 0.7s
#
# 2017-04-10 16:55:32 (6.55 MB/s) - ‘nhgis0013_csv.zip’ saved [4739822/4739822]

# %%
# !unzip nhgis0013_csv.zip
# Out:
# Archive:  nhgis0013_csv.zip
#   inflating: nhgis0013_csv/nhgis0013_ds172_2010_block.csv
#   inflating: nhgis0013_csv/nhgis0013_ds172_2010_block_codebook.txt

# %%
# !wget https://data2.nhgis.org/extracts/97092/12/nhgis0012_csv.zip
# Out:
# --2017-04-10 16:56:22--  https://data2.nhgis.org/extracts/97092/12/nhgis0012_csv.zip
# Resolving data2.nhgis.org (data2.nhgis.org)... 128.101.163.216
# Connecting to data2.nhgis.org (data2.nhgis.org)|128.101.163.216|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3793208 (3.6M) [application/zip]
# Saving to: ‘nhgis0012_csv.zip’
#
# nhgis0012_csv.zip   100%[===================>]   3.62M  6.35MB/s    in 0.6s
#
# 2017-04-10 16:56:23 (6.35 MB/s) - ‘nhgis0012_csv.zip’ saved [3793208/3793208]

# %%
# !unzip nhgis0012_csv.zip
# Out:
# Archive:  nhgis0012_csv.zip
#   inflating: nhgis0012_csv/nhgis0012_ds148_2000_block.csv
#   inflating: nhgis0012_csv/nhgis0012_ds147_2000_block_codebook.txt
#   inflating: nhgis0012_csv/nhgis0012_ds147_2000_block.csv
#   inflating: nhgis0012_csv/nhgis0012_ds148_2000_block_codebook.txt

# %%
# !ls  columncache/census2000_block2010 | cat
# Out:
# h001001.numpy
# h002001.numpy
# h002002.numpy
# h002003.numpy
# h002004.numpy
# h002005.numpy
# h002006.numpy
# h003001.numpy
# h003002.numpy
# h003003.numpy
# h004001.numpy
# h004002.numpy
# h004003.numpy
# h005001.numpy
# h005002.numpy
# h005003.numpy
# h005004.numpy
# h005005.numpy
# h005006.numpy
# h005007.numpy
# h006001.numpy
# h006002.numpy
# h006003.numpy
# h006004.numpy
# h006005.numpy
# h006006.numpy
# h006007.numpy
# h006008.numpy
# h007001.numpy
# h007002.numpy
# h007003.numpy
# h007004.numpy
# h007005.numpy
# h007006.numpy
# h007007.numpy
# h007008.numpy
# h007009.numpy
# h007010.numpy
# h007011.numpy
# h007012.numpy
# h007013.numpy
# h007014.numpy
# h007015.numpy
# h007016.numpy
# h007017.numpy
# h008001.numpy
# h008002.numpy
# h008003.numpy
# h008004.numpy
# h008005.numpy
# h008006.numpy
# h008007.numpy
# h009001.numpy
# h009002.numpy
# h009003.numpy
# h009004.numpy
# h009005.numpy
# h009006.numpy
# h009007.numpy
# h009008.numpy
# h009009.numpy
# h009010.numpy
# ...

# %%
# !cat nhgis0012_csv/nhgis0012_ds148_2000_block_codebook.txt
# Out:
# --------------------------------------------------------------------------------
# Codebook for NHGIS data file 'nhgis0012_ds148_2000_block'
# --------------------------------------------------------------------------------
#
# Contents
#     - Data Summary
#     - Data Dictionary
#     - Citation and Use
#
# Additional documentation on NHGIS data sources is available at:
#     https://www.nhgis.org/documentation/tabular-data
#
# --------------------------------------------------------------------------------
# Data Summary
# --------------------------------------------------------------------------------
#
# Year:             2000
# Geographic level: Block (by State--County--Census Tract)
# Extent:           District Of Columbia
# Dataset:          2000 Census: SF 1S - Urban/Rural Counts [Blocks, Block Group Parts & Tract Parts]
#    NHGIS code:    2000_SF1S
#    NHGIS ID:      ds148
#
# Tables:
#
# 1. Total Population
#    Universe:    Persons
#    Source code: NP001A
# ...

# %%
# !cat nhgis0012_csv/nhgis0012_ds147_2000_block_codebook.txt
# Out:
# --------------------------------------------------------------------------------
# Codebook for NHGIS data file 'nhgis0012_ds147_2000_block'
# --------------------------------------------------------------------------------
#
# Contents
#     - Data Summary
#     - Data Dictionary
#     - Citation and Use
#
# Additional documentation on NHGIS data sources is available at:
#     https://www.nhgis.org/documentation/tabular-data
#
# --------------------------------------------------------------------------------
# Data Summary
# --------------------------------------------------------------------------------
#
# Year:             2000
# Geographic level: Block (by State--County--Census Tract)
# Extent:           District Of Columbia
# Dataset:          2000 Census: SF 1b - 100% Data [Blocks & Block Groups]
#    NHGIS code:    2000_SF1b
#    NHGIS ID:      ds147
#
# Tables:
#
# 1. Total Population
#    Universe:    Persons
#    Source code: NP001A
#    NHGIS code:  FXS
#
# ...

# %%
# !cat nhgis0013_csv/nhgis0013_ds172_2010_block_codebook.txt
# Out:
# --------------------------------------------------------------------------------
# Codebook for NHGIS data file 'nhgis0013_ds172_2010_block'
# --------------------------------------------------------------------------------
#
# Contents
#     - Data Summary
#     - Data Dictionary
#     - Citation and Use
#
# Additional documentation on NHGIS data sources is available at:
#     https://www.nhgis.org/documentation/tabular-data
#
# --------------------------------------------------------------------------------
# Data Summary
# --------------------------------------------------------------------------------
#
# Year:             2010
# Geographic level: Block (by State--County--Census Tract)
# Extent:           District Of Columbia
# Dataset:          2010 Census: SF 1a - P & H Tables [Blocks & Larger Areas]
#    NHGIS code:    2010_SF1a
#    NHGIS ID:      ds172
# Breakdown(s):     Geographic Subarea:
#                      Total area (00)
#
# Tables:
#
# 1. Total Population
# ...

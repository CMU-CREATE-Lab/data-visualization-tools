# %% [markdown]
# TO DO
# -----
#
# * Renumber notebook names to reflect correct order of execution;  03 and 04 should swap
# * Bump process pool to full amount (e.g. 32 on earthserve2) but limit concurrent psql queries to maybe 8 using Semaphore
# * Write points, maybe every 1MB or so, directly to disk to avoid filling up RAM, using append mode and a semaphore to protect access
# * Scramble the points at the end

# %%
import array, csv, fcntl, json, math, multiprocessing, os, random, re, shutil
import shapely, shapely.wkb, struct, subprocess, sys, threading, urllib2

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

# %%
try:
    import pyproj
except:
    # !pip install pyproj
    import pyproj

# %%
try:
    import shapely
except:
    # !pip install shapely==1.6b2
    import shapely

# %%
year = 2011
jt = 'JT01'

# %%
def LonLatToPixelXY(lonlat, scale = 1.):
    (lon, lat) = lonlat
    x = (lon + 180.0) * 256.0 / 360.0
    y = 128.0 - math.log(math.tan((lat + 90.0) * math.pi / 360.0)) * 128.0 / math.pi
    return [x*scale, y*scale]

# %%
import psycopg2
from random import uniform

def randomPoint(poly):
    bbox = poly.bounds
    l,b,r,t = bbox
    while True:
        point = shapely.geometry.point.Point(uniform(l,r),uniform(t,b))
        if point is None:
            break
        if poly.contains(point):
            break
    return point.__geo_interface__['coordinates']

# %%
def split_list(alist, num_chunks=1):
    chunk_size = (len(alist) + num_chunks - 1) // num_chunks
    return [ alist[i*chunk_size : (i+1)*chunk_size] 
             for i in xrange(num_chunks) ]

# %%
def pack_color(color):
    return color['r'] + color['g'] * 256.0 + color['b'] * 256.0 * 256.0;

def unpack_color(f):
    b = floor(f / 256.0 / 256.0)
    g = floor((f - b * 256.0 * 256.0) / 256.0)
    r = floor(f - b * 256.0 * 256.0 - g * 256.0)
    return {'r':r,'g':g,'b':b}

se01_color = {'r':25, 'g':75, 'b':255}
se02_color = {'r':20, 'g':138, 'b':9}
se03_color = {'r':227, 'g':30, 'b':30}
nonemployed_color = {'r':0, 'g':0, 'b':0}

# %% [markdown]
# Compute dot home and work locations from LODES 3 income levels
# --------------------------------------------------------------

# %%
max_gid_query = 'SELECT gid FROM od_{jt}_{year} ORDER BY gid DESC LIMIT 1'.format(jt=jt, year=year)
max_gid = query_psql(max_gid_query)[0][0]
print 'Maximum gid in od_{jt}_{year} is {max_gid}'.format(jt=jt, year=year, max_gid=max_gid)
# Out:
# Execution of SELECT gid FROM od_JT01_2011 ORDER BY gid DESC LIMIT 1
# took 0.00324702 seconds and returned 1 rows
# Maximum gid in od_JT01_2011 is 106605364

# %%
max_psql_parallelism = 8
psql_semaphore = multiprocessing.Semaphore(max_psql_parallelism)

def query_psql_throttled(query, quiet=False):
    psql_semaphore.acquire()
    try:
        rows = query_psql(query, quiet=quiet)
    finally:
        psql_semaphore.release()
    return rows

# %%
def write_points(points):
    fcntl.flock(point_output, fcntl.LOCK_EX)
    try:
        point_output.write(''.join(points))
        point_output.flush()
    finally:
        fcntl.flock(point_output, fcntl.LOCK_UN)

def process_employment_shard(gid_start, gid_end):
    query = (
            "SELECT w.geom, h.geom, od.se01, od.se02, od.se03 "
            "FROM od_{jt}_{year} od  "
            "JOIN tl_2010_tabblock10 w ON od.w_geocode = w.geoid10 "
            "JOIN tl_2010_tabblock10 h ON od.h_geocode = h.geoid10 "
            "WHERE od.gid BETWEEN {gid_start} AND {gid_end} "
            #"AND od.h_geocode LIKE '42%' "
            ).format(jt=jt, year=year, gid_start=gid_start, gid_end=gid_end)
    rows = query_psql_throttled(query, quiet=True)
    begin_time = time.time()
    if len(rows) == 0:
        sys.stdout.write("No rows, aborting shard %d\n" % gid_start)
        return []
    sys.stdout.write("Starting shard %d with %d rows\n" % (gid_start, len(rows)))

    points = []
    wgs84_geod = pyproj.Geod(ellps='WGS84')
    for (workGeom, homeGeom, se01, se02, se03) in rows:
        workPolygon = shapely.wkb.loads(workGeom, hex=True)
        homePolygon = shapely.wkb.loads(homeGeom, hex=True)

        # Compute distance on the sphere
        dist = wgs84_geod.inv(workPolygon.centroid.x, workPolygon.centroid.y,
                              homePolygon.centroid.x, homePolygon.centroid.y)[2]
        
        for (count, color) in [(se01, se01_color), (se02, se02_color), (se03, se03_color)]:
            pcolor = pack_color(color)
            for i in range(count):
                wpoint = LonLatToPixelXY(randomPoint(workPolygon))
                hpoint = LonLatToPixelXY(randomPoint(homePolygon))
                points.append(struct.pack('<ffffff', wpoint[0], wpoint[1], hpoint[0], hpoint[1], dist, pcolor))
        
        if len(points) >= 10000:
            write_points(points)
            points = []
    write_points(points)
    sys.stdout.write("Finished shard %d with %d rows in %g seconds\n" % (gid_start, len(rows), time.time() - begin_time))

# %%
dest = 'od-{jt}-{year}.bin'.format(jt=jt, year=year)
print "Opening binary file %s for appending data" % dest

open(dest, 'wb') # truncate the file
point_output = open(dest, 'ab')

shard_size = 50000
pool = multiprocessing.Pool()

results = []

print "Starting shards with maximum index %d" % max_gid

for gid_start in range(0, max_gid + 1, shard_size):
    results.append(pool.apply_async(process_employment_shard, (gid_start, gid_start + shard_size - 1)))

print "No more shards to create.  Waiting for shards to finish."

pool.close()
pool.join()

for res in results:
    res.get()
# Out:
# Opening binary file od-JT01-2011.bin for appending data
# Starting shard 0 with 49999 rows
# Starting shard 200000 with 50000 rows
# Starting shard 150000 with 50000 rows
# Starting shard 50000 with 50000 rows
# Starting shard 250000 with 50000 rows
# Starting shard 100000 with 50000 rows
# Starting shard 300000 with 50000 rows
# Starting shard 350000 with 50000 rows
# Starting shard 400000 with 50000 rows
# Starting shard 450000 with 50000 rows
# Starting shard 500000 with 50000 rows
# Starting shard 550000 with 50000 rows
# Starting shard 600000 with 50000 rows
# Starting shard 650000 with 50000 rows
# Starting shard 700000 with 50000 rows
# Starting shard 750000 with 50000 rows
# Starting shard 800000 with 50000 rows
# Starting shard 950000 with 50000 rows
# Starting shard 900000 with 50000 rows
# Starting shard 850000 with 50000 rows
# Starting shard 1000000 with 50000 rows
# Starting shard 1050000 with 50000 rows
# Starting shard 1100000 with 50000 rows
# Starting shard 1150000 with 50000 rows
# Starting shard 1200000 with 50000 rows
# Starting shard 1250000 with 50000 rows
# Starting shard 1300000 with 50000 rows
# Starting shard 1350000 with 50000 rows
# Starting shard 1450000 with 50000 rows
# Starting shard 1400000 with 50000 rows
# Starting shard 1500000 with 50000 rows
# Starting shard 1550000 with 50000 rows
# Finished shard 300000 with 50000 rows in 97.0741 seconds
# Finished shard 150000 with 50000 rows in 98.0646 seconds
# Finished shard 350000 with 50000 rows in 98.0149 seconds
# Finished shard 200000 with 50000 rows in 100.476 seconds
# Finished shard 100000 with 50000 rows in 101.697 seconds
# Starting shard 1600000 with 50000 rows
# Finished shard 450000 with 50000 rows in 97.8299 seconds
# Starting shard 1650000 with 50000 rows
# Starting shard 1700000 with 50000 rows
# Finished shard 250000 with 50000 rows in 104.539 seconds
# Finished shard 50000 with 50000 rows in 105.315 seconds
# Finished shard 400000 with 50000 rows in 100.934 seconds
# Starting shard 1750000 with 50000 rows
# Starting shard 1800000 with 50000 rows
# Starting shard 1850000 with 50000 rows
# Finished shard 550000 with 50000 rows in 103.346 seconds
# Finished shard 500000 with 50000 rows in 103.468 seconds
# Starting shard 1900000 with 50000 rows
# Finished shard 600000 with 50000 rows in 104.146 seconds
# Starting shard 1950000 with 50000 rows
# Finished shard 1000000 with 50000 rows in 100.498 seconds
# Starting shard 2000000 with 50000 rows
# Finished shard 1050000 with 50000 rows in 100.833 seconds
# Finished shard 800000 with 50000 rows in 102.236 seconds
# Finished shard 950000 with 50000 rows in 101.803 seconds
# Finished shard 1100000 with 50000 rows in 100.874 seconds
# Finished shard 650000 with 50000 rows in 107.265 seconds
# Starting shard 2050000 with 50000 rows
# Starting shard 2100000 with 50000 rows
# Finished shard 700000 with 50000 rows in 108.508 seconds
# Starting shard 2150000 with 50000 rows
# Finished shard 850000 with 50000 rows in 105.516 seconds
# Finished shard 1150000 with 50000 rows in 104.01 seconds
# Starting shard 2200000 with 50000 rows
# Starting shard 2250000 with 50000 rows
# Starting shard 2350000 with 50000 rows
# Starting shard 2300000 with 50000 rows
# Finished shard 900000 with 50000 rows in 107.449 seconds
# Starting shard 2400000 with 50000 rows
# Finished shard 1300000 with 50000 rows in 101.755 seconds
# Finished shard 750000 with 50000 rows in 111.618 seconds
# Finished shard 1350000 with 50000 rows in 102.133 seconds
# Starting shard 2450000 with 50000 rows
# Finished shard 1400000 with 50000 rows in 102.607 seconds
# Starting shard 2500000 with 50000 rows
# Finished shard 1200000 with 50000 rows in 105.399 seconds
# Starting shard 2550000 with 50000 rows
# Finished shard 1550000 with 50000 rows in 103.917 seconds
# Starting shard 2600000 with 50000 rows
# Finished shard 1250000 with 50000 rows in 106.855 seconds
# Starting shard 2650000 with 50000 rows
# Starting shard 2700000 with 50000 rows
# Starting shard 2800000 with 50000 rows
# Starting shard 2750000 with 50000 rows
# Finished shard 1500000 with 50000 rows in 107.203 seconds
# Starting shard 2850000 with 50000 rows
# Starting shard 2900000 with 50000 rows
# Finished shard 1450000 with 50000 rows in 108.789 seconds
# Finished shard 0 with 49999 rows in 126.227 seconds
# Starting shard 2950000 with 50000 rows
# Starting shard 3000000 with 50000 rows
# Starting shard 3050000 with 50000 rows
# Starting shard 3100000 with 50000 rows
# Starting shard 3150000 with 50000 rows
# Finished shard 1600000 with 50000 rows in 104.528 seconds
# Finished shard 1650000 with 50000 rows in 105.398 seconds
# Finished shard 1700000 with 50000 rows in 105.149 seconds
# Finished shard 1750000 with 50000 rows in 103.547 seconds
# Finished shard 1900000 with 50000 rows in 100.105 seconds
# Finished shard 1950000 with 50000 rows in 100.383 seconds
# Starting shard 3200000 with 50000 rows
# Finished shard 2000000 with 50000 rows in 101.817 seconds
# Starting shard 3250000 with 50000 rows
# Starting shard 3300000 with 50000 rows
# Starting shard 3350000 with 50000 rows
# Finished shard 2300000 with 50000 rows in 96.4553 seconds
# Starting shard 3400000 with 50000 rows
# Finished shard 2250000 with 50000 rows in 97.7917 seconds
# Finished shard 1850000 with 50000 rows in 106.848 seconds
# Starting shard 3450000 with 50000 rows
# Finished shard 2050000 with 50000 rows in 103.035 seconds
# Starting shard 3500000 with 50000 rows
# Finished shard 2500000 with 50000 rows in 98.4903 seconds
# Finished shard 2450000 with 50000 rows in 99.2517 seconds
# Finished shard 2100000 with 50000 rows in 104.354 seconds
# Starting shard 3550000 with 50000 rows
# Starting shard 3600000 with 50000 rows
# Starting shard 3650000 with 50000 rows
# Finished shard 2550000 with 50000 rows in 98.9833 seconds
# Starting shard 3700000 with 50000 rows
# Finished shard 2200000 with 50000 rows in 104.432 seconds
# Finished shard 2900000 with 50000 rows in 96.519 seconds
# Finished shard 1800000 with 50000 rows in 114.114 seconds
# Finished shard 2400000 with 50000 rows in 104.859 seconds
# Starting shard 3800000 with 50000 rows
# Finished shard 2150000 with 50000 rows in 107.945 seconds
# Starting shard 3750000 with 50000 rows
# Starting shard 3850000 with 50000 rows
# Finished shard 2600000 with 50000 rows in 101.354 seconds
# Finished shard 2350000 with 50000 rows in 105.918 seconds
# Finished shard 2650000 with 50000 rows in 100.981 seconds
# Finished shard 2750000 with 50000 rows in 100.228 seconds
# Starting shard 3900000 with 50000 rows
# Finished shard 2950000 with 50000 rows in 98.294 seconds
# Finished shard 2700000 with 50000 rows in 102.638 seconds
# Starting shard 4000000 with 50000 rows
# Starting shard 3950000 with 50000 rows
# Finished shard 2850000 with 50000 rows in 101.872 seconds
# Starting shard 4050000 with 50000 rows
# Starting shard 4150000 with 50000 rows
# Starting shard 4100000 with 50000 rows
# Finished shard 2800000 with 50000 rows in 103.942 seconds
# Starting shard 4200000 with 50000 rows
# Starting shard 4250000 with 50000 rows
# Finished shard 3100000 with 50000 rows in 98.333 seconds
# Starting shard 4300000 with 50000 rows
# Finished shard 3050000 with 50000 rows in 100.639 seconds
# Starting shard 4350000 with 50000 rows
# Finished shard 3000000 with 50000 rows in 102.133 seconds
# Starting shard 4400000 with 50000 rows
# Finished shard 3150000 with 50000 rows in 100.245 seconds
# Starting shard 4450000 with 50000 rows
# Starting shard 4550000 with 50000 rows
# Starting shard 4500000 with 50000 rows
# Starting shard 4600000 with 50000 rows
# Starting shard 4650000 with 50000 rows
# Starting shard 4700000 with 50000 rows
# Starting shard 4750000 with 50000 rows
# Finished shard 3200000 with 50000 rows in 103.553 seconds
# Finished shard 3500000 with 50000 rows in 99.559 seconds
# Finished shard 3450000 with 50000 rows in 101.823 seconds
# Finished shard 3300000 with 50000 rows in 104.726 seconds
# Finished shard 3250000 with 50000 rows in 105.879 seconds
# Finished shard 3550000 with 50000 rows in 100.822 seconds
# Starting shard 4800000 with 50000 rows
# Finished shard 3400000 with 50000 rows in 105.264 seconds
# Finished shard 3350000 with 50000 rows in 105.994 seconds
# Finished shard 3650000 with 50000 rows in 101.341 seconds
# Finished shard 3700000 with 50000 rows in 100.763 seconds
# Starting shard 4850000 with 50000 rows
# Finished shard 3600000 with 50000 rows in 103.124 seconds
# Starting shard 4900000 with 50000 rows
# Starting shard 4950000 with 50000 rows
# Finished shard 3850000 with 50000 rows in 101.017 seconds
# Finished shard 3800000 with 50000 rows in 101.232 seconds
# Finished shard 3750000 with 50000 rows in 101.421 seconds
# Finished shard 4050000 with 50000 rows in 97.815 seconds
# Starting shard 5000000 with 50000 rows
# Starting shard 5050000 with 50000 rows
# Starting shard 5100000 with 50000 rows
# Finished shard 4150000 with 50000 rows in 98.071 seconds
# Finished shard 4100000 with 50000 rows in 97.8724 seconds
# Starting shard 5150000 with 50000 rows
# Starting shard 5200000 with 50000 rows
# Finished shard 4200000 with 50000 rows in 99.0218 seconds
# Starting shard 5250000 with 50000 rows
# Starting shard 5300000 with 50000 rows
# Starting shard 5350000 with 50000 rows
# Starting shard 5400000 with 50000 rows
# Finished shard 4250000 with 50000 rows in 101.376 seconds
# Starting shard 5450000 with 50000 rows
# Starting shard 5500000 with 50000 rows
# Starting shard 5550000 with 50000 rows
# Starting shard 5600000 with 50000 rows
# Finished shard 3950000 with 50000 rows in 104.956 seconds
# Finished shard 4000000 with 50000 rows in 105.553 seconds
# Finished shard 4400000 with 50000 rows in 101.493 seconds
# Starting shard 5650000 with 50000 rows
# Finished shard 4700000 with 50000 rows in 99.2024 seconds
# Starting shard 5700000 with 50000 rows
# Finished shard 4650000 with 50000 rows in 100.109 seconds
# Finished shard 4550000 with 50000 rows in 101.638 seconds
# Finished shard 4350000 with 50000 rows in 105.085 seconds
# Starting shard 5750000 with 50000 rows
# Finished shard 4600000 with 50000 rows in 102.718 seconds
# Finished shard 4300000 with 50000 rows in 106.527 seconds
# Starting shard 5800000 with 50000 rows
# Starting shard 5850000 with 50000 rows
# Finished shard 4450000 with 50000 rows in 106.035 seconds
# Finished shard 4500000 with 50000 rows in 106.313 seconds
# Starting shard 5950000 with 50000 rows
# Starting shard 6000000 with 50000 rows
# Starting shard 5900000 with 50000 rows
# Finished shard 4750000 with 50000 rows in 103.296 seconds
# Starting shard 6050000 with 50000 rows
# Starting shard 6100000 with 50000 rows
# Starting shard 6150000 with 50000 rows
# Starting shard 6200000 with 50000 rows
# Finished shard 3900000 with 50000 rows in 116.918 seconds
# Starting shard 6250000 with 50000 rows
# Starting shard 6300000 with 50000 rows
# Starting shard 6350000 with 50000 rows
# Finished shard 4800000 with 50000 rows in 106.663 seconds
# Finished shard 4850000 with 50000 rows in 104.919 seconds
# Starting shard 6400000 with 50000 rows
# Finished shard 5400000 with 50000 rows in 101.961 seconds
# Finished shard 5300000 with 50000 rows in 103.426 seconds
# Finished shard 5000000 with 50000 rows in 107.409 seconds
# Finished shard 5500000 with 50000 rows in 101.729 seconds
# Starting shard 6450000 with 50000 rows
# Finished shard 5100000 with 50000 rows in 107.108 seconds
# Finished shard 5150000 with 50000 rows in 107.298 seconds
# Finished shard 5550000 with 50000 rows in 102.593 seconds
# Finished shard 4950000 with 50000 rows in 109.858 seconds
# Finished shard 5600000 with 50000 rows in 102.836 seconds
# Finished shard 4900000 with 50000 rows in 111.251 seconds
# Finished shard 5350000 with 50000 rows in 107.076 seconds
# Finished shard 5050000 with 50000 rows in 111.063 seconds
# Starting shard 6500000 with 50000 rows
# Starting shard 6550000 with 50000 rows
# Starting shard 6600000 with 50000 rows
# Starting shard 6650000 with 50000 rows
# Starting shard 6700000 with 50000 rows
# Starting shard 6750000 with 50000 rows
# Starting shard 6800000 with 50000 rows
# Finished shard 5650000 with 50000 rows in 105.608 seconds
# Finished shard 5450000 with 50000 rows in 107.926 seconds
# Starting shard 6850000 with 50000 rows
# Finished shard 5200000 with 50000 rows in 111.879 seconds
# Finished shard 5700000 with 50000 rows in 105.582 seconds
# Finished shard 5800000 with 50000 rows in 104.056 seconds
# Starting shard 6900000 with 50000 rows
# Starting shard 6950000 with 50000 rows
# Finished shard 6100000 with 50000 rows in 100.524 seconds
# Finished shard 6050000 with 50000 rows in 101.692 seconds
# Finished shard 6150000 with 50000 rows in 100.818 seconds
# Finished shard 5250000 with 50000 rows in 114.164 seconds
# Starting shard 7000000 with 50000 rows
# Starting shard 7150000 with 50000 rows
# Finished shard 5750000 with 50000 rows in 106.772 seconds
# Starting shard 7100000 with 50000 rows
# Starting shard 7050000 with 50000 rows
# Starting shard 7200000 with 50000 rows
# Finished shard 6200000 with 50000 rows in 102.029 seconds
# Starting shard 7250000 with 50000 rows
# Starting shard 7300000 with 50000 rows
# Starting shard 7350000 with 50000 rows
# Finished shard 6300000 with 50000 rows in 102.203 seconds
# Starting shard 7400000 with 50000 rows
# Finished shard 5950000 with 50000 rows in 107.679 seconds
# Starting shard 7500000 with 50000 rows
# Finished shard 5900000 with 50000 rows in 108.213 seconds
# Starting shard 7450000 with 50000 rows
# Starting shard 7550000 with 50000 rows
# Finished shard 5850000 with 50000 rows in 111.043 seconds
# Starting shard 7600000 with 50000 rows
# Starting shard 7650000 with 50000 rows
# Starting shard 7700000 with 50000 rows
# Finished shard 6250000 with 50000 rows in 107.885 seconds
# Starting shard 7750000 with 50000 rows
# Starting shard 7800000 with 50000 rows
# Finished shard 6000000 with 50000 rows in 114.661 seconds
# Finished shard 6350000 with 50000 rows in 107.328 seconds
# Starting shard 7850000 with 50000 rows
# Starting shard 7900000 with 50000 rows
# Starting shard 7950000 with 50000 rows
# Finished shard 6400000 with 50000 rows in 105.693 seconds
# Finished shard 6450000 with 50000 rows in 104.409 seconds
# Starting shard 8000000 with 50000 rows
# Finished shard 6850000 with 50000 rows in 102.652 seconds
# Starting shard 8050000 with 50000 rows
# Finished shard 7100000 with 50000 rows in 99.4573 seconds
# Finished shard 7150000 with 50000 rows in 99.7537 seconds
# Finished shard 7200000 with 50000 rows in 101.306 seconds
# Finished shard 6950000 with 50000 rows in 103.645 seconds
# Finished shard 7300000 with 50000 rows in 99.6276 seconds
# Starting shard 8100000 with 50000 rows
# Finished shard 6550000 with 50000 rows in 109.662 seconds
# Finished shard 6750000 with 50000 rows in 108.756 seconds
# Starting shard 8150000 with 50000 rows
# Finished shard 6800000 with 50000 rows in 108.805 seconds
# Starting shard 8200000 with 50000 rows
# Finished shard 6500000 with 50000 rows in 110.76 seconds
# Finished shard 6600000 with 50000 rows in 110.752 seconds
# Finished shard 7250000 with 50000 rows in 102.671 seconds
# Finished shard 7350000 with 50000 rows in 101.537 seconds
# Finished shard 7400000 with 50000 rows in 101.844 seconds
# Finished shard 6900000 with 50000 rows in 108.095 seconds
# Starting shard 8300000 with 50000 rows
# Starting shard 8250000 with 50000 rows
# Starting shard 8350000 with 50000 rows
# Starting shard 8400000 with 50000 rows
# Starting shard 8450000 with 50000 rows
# Finished shard 7000000 with 50000 rows in 108.987 seconds
# Starting shard 8500000 with 50000 rows
# Starting shard 8550000 with 50000 rows
# Finished shard 7700000 with 50000 rows in 100.452 seconds
# Finished shard 7650000 with 50000 rows in 100.737 seconds
# Starting shard 8600000 with 50000 rows
# Finished shard 6700000 with 50000 rows in 114.973 seconds
# Starting shard 8650000 with 50000 rows
# Finished shard 7750000 with 50000 rows in 101.318 seconds
# Finished shard 7600000 with 50000 rows in 104.336 seconds
# Finished shard 7550000 with 50000 rows in 105.74 seconds
# Starting shard 8750000 with 50000 rows
# Starting shard 8700000 with 50000 rows
# Finished shard 6650000 with 50000 rows in 117.011 seconds
# Starting shard 8800000 with 50000 rows
# Starting shard 8850000 with 50000 rows
# Starting shard 8900000 with 50000 rows
# Starting shard 8950000 with 50000 rows
# Starting shard 9000000 with 50000 rows
# Finished shard 7500000 with 50000 rows in 109.809 seconds
# Starting shard 9050000 with 50000 rows
# Finished shard 7950000 with 50000 rows in 99.6135 seconds
# Finished shard 7800000 with 50000 rows in 105.527 seconds
# Starting shard 9200000 with 50000 rows
# Starting shard 9100000 with 50000 rows
# Starting shard 9150000 with 50000 rows
# Finished shard 7450000 with 50000 rows in 112.542 seconds
# Finished shard 7050000 with 50000 rows in 117.361 seconds
# Finished shard 7850000 with 50000 rows in 105.422 seconds
# Starting shard 9250000 with 50000 rows
# Starting shard 9300000 with 50000 rows
# Starting shard 9350000 with 50000 rows
# Starting shard 9500000 with 50000 rows
# Starting shard 9400000 with 50000 rows
# Starting shard 9450000 with 50000 rows
# Finished shard 7900000 with 50000 rows in 107.549 seconds
# Starting shard 9550000 with 50000 rows
# Finished shard 8050000 with 50000 rows in 101.412 seconds
# Finished shard 8150000 with 50000 rows in 97.993 seconds
# Finished shard 8100000 with 50000 rows in 99.888 seconds
# Finished shard 8000000 with 50000 rows in 105.998 seconds
# Starting shard 9600000 with 50000 rows
# Finished shard 8250000 with 50000 rows in 98.2826 seconds
# Finished shard 8300000 with 50000 rows in 99.2013 seconds
# Finished shard 8200000 with 50000 rows in 101.851 seconds
# Starting shard 9650000 with 50000 rows
# Starting shard 9700000 with 50000 rows
# Starting shard 9750000 with 50000 rows
# Finished shard 8550000 with 50000 rows in 99.3839 seconds
# Finished shard 8400000 with 50000 rows in 101.307 seconds
# Finished shard 8650000 with 50000 rows in 98.8658 seconds
# Starting shard 9800000 with 50000 rows
# Starting shard 9850000 with 50000 rows
# Finished shard 8500000 with 50000 rows in 102.107 seconds
# Finished shard 8750000 with 50000 rows in 99.3657 seconds
# Starting shard 9900000 with 50000 rows
# Finished shard 8950000 with 50000 rows in 98.2115 seconds
# Finished shard 8600000 with 50000 rows in 102.087 seconds
# Finished shard 8850000 with 50000 rows in 99.7376 seconds
# Finished shard 8350000 with 50000 rows in 105.008 seconds
# Starting shard 9950000 with 50000 rows
# Finished shard 8800000 with 50000 rows in 100.979 seconds
# Starting shard 10000000 with 50000 rows
# Starting shard 10050000 with 50000 rows
# Finished shard 9050000 with 50000 rows in 99.2137 seconds
# Finished shard 8450000 with 50000 rows in 106.133 seconds
# Finished shard 9000000 with 50000 rows in 100.246 seconds
# Finished shard 8700000 with 50000 rows in 103.421 seconds
# Starting shard 10100000 with 50000 rows
# Starting shard 10150000 with 50000 rows
# Starting shard 10250000 with 50000 rows
# Starting shard 10200000 with 50000 rows
# Starting shard 10350000 with 50000 rows
# Starting shard 10300000 with 50000 rows
# Finished shard 9100000 with 50000 rows in 101.56 seconds
# Starting shard 10400000 with 50000 rows
# Finished shard 9150000 with 50000 rows in 101.618 seconds
# Finished shard 9250000 with 50000 rows in 100.466 seconds
# Starting shard 10450000 with 50000 rows
# Starting shard 10500000 with 50000 rows
# Starting shard 10550000 with 50000 rows
# Starting shard 10600000 with 50000 rows
# Finished shard 9200000 with 50000 rows in 104.369 seconds
# Finished shard 9350000 with 50000 rows in 100.673 seconds
# Finished shard 9300000 with 50000 rows in 102.007 seconds
# Finished shard 8900000 with 50000 rows in 107.937 seconds
# Starting shard 10650000 with 50000 rows
# Finished shard 9500000 with 50000 rows in 100.249 seconds
# Starting shard 10700000 with 50000 rows
# Starting shard 10750000 with 50000 rows
# Starting shard 10800000 with 50000 rows
# Starting shard 10850000 with 50000 rows
# Finished shard 9400000 with 50000 rows in 103.586 seconds
# Starting shard 10900000 with 50000 rows
# Starting shard 10950000 with 50000 rows
# Starting shard 11000000 with 50000 rows
# Finished shard 9450000 with 50000 rows in 106.037 seconds
# Finished shard 9550000 with 50000 rows in 102.648 seconds
# Starting shard 11050000 with 50000 rows
# Starting shard 11100000 with 50000 rows
# Starting shard 11150000 with 50000 rows
# Finished shard 9650000 with 50000 rows in 103.852 seconds
# Finished shard 9900000 with 50000 rows in 101.326 seconds
# Finished shard 10350000 with 50000 rows in 96.4299 seconds
# Finished shard 9750000 with 50000 rows in 105.749 seconds
# Finished shard 9700000 with 50000 rows in 106.845 seconds
# Starting shard 11200000 with 50000 rows
# Finished shard 10200000 with 50000 rows in 98.3555 seconds
# Finished shard 9600000 with 50000 rows in 110.269 seconds
# Finished shard 10250000 with 50000 rows in 99.432 seconds
# Finished shard 9800000 with 50000 rows in 106.048 seconds
# Finished shard 10300000 with 50000 rows in 99.3751 seconds
# Finished shard 9950000 with 50000 rows in 103.857 seconds
# Starting shard 11250000 with 50000 rows
# Finished shard 10150000 with 50000 rows in 102.34 seconds
# Starting shard 11300000 with 50000 rows
# Starting shard 11350000 with 50000 rows
# Finished shard 10400000 with 50000 rows in 100.319 seconds
# Starting shard 11400000 with 50000 rows
# Starting shard 11450000 with 50000 rows
# Starting shard 11500000 with 50000 rows
# Finished shard 10450000 with 50000 rows in 101.09 seconds
# Finished shard 10600000 with 50000 rows in 100.094 seconds
# Starting shard 11550000 with 50000 rows
# Starting shard 11600000 with 50000 rows
# Finished shard 10050000 with 50000 rows in 106.57 seconds
# Starting shard 11650000 with 50000 rows
# Finished shard 9850000 with 50000 rows in 111.264 seconds
# Finished shard 10500000 with 50000 rows in 102.859 seconds
# Starting shard 11700000 with 50000 rows
# Starting shard 11750000 with 50000 rows
# Finished shard 10000000 with 50000 rows in 108.808 seconds
# Finished shard 10100000 with 50000 rows in 107.559 seconds
# Starting shard 11800000 with 50000 rows
# Finished shard 10700000 with 50000 rows in 101.76 seconds
# Starting shard 11850000 with 50000 rows
# Starting shard 11950000 with 50000 rows
# Starting shard 11900000 with 50000 rows
# Finished shard 10650000 with 50000 rows in 104.118 seconds
# Finished shard 10850000 with 50000 rows in 101.59 seconds
# Starting shard 12000000 with 50000 rows
# Starting shard 12150000 with 50000 rows
# Starting shard 12100000 with 50000 rows
# Finished shard 10550000 with 50000 rows in 107.453 seconds
# Starting shard 12050000 with 50000 rows
# Starting shard 12200000 with 50000 rows
# Finished shard 10950000 with 50000 rows in 103.738 seconds
# Starting shard 12250000 with 50000 rows
# Starting shard 12300000 with 50000 rows
# Starting shard 12350000 with 50000 rows
# Finished shard 10750000 with 50000 rows in 109.193 seconds
# Finished shard 10800000 with 50000 rows in 107.7 seconds
# Starting shard 12400000 with 50000 rows
# Finished shard 10900000 with 50000 rows in 108.543 seconds
# Starting shard 12450000 with 50000 rows
# Starting shard 12500000 with 50000 rows
# Starting shard 12550000 with 50000 rows
# Finished shard 11150000 with 50000 rows in 104.811 seconds
# Finished shard 11100000 with 50000 rows in 106.156 seconds
# Finished shard 11050000 with 50000 rows in 109.43 seconds
# Finished shard 11000000 with 50000 rows in 111.683 seconds
# Starting shard 12600000 with 50000 rows
# Starting shard 12650000 with 50000 rows
# Starting shard 12700000 with 50000 rows
# Starting shard 12750000 with 50000 rows
# Finished shard 11200000 with 50000 rows in 103.46 seconds
# Finished shard 11450000 with 50000 rows in 100.829 seconds
# Finished shard 11250000 with 50000 rows in 103.175 seconds
# Starting shard 12800000 with 50000 rows
# Starting shard 12850000 with 50000 rows
# Starting shard 12900000 with 50000 rows
# Finished shard 11750000 with 50000 rows in 103.943 seconds
# Finished shard 11800000 with 50000 rows in 103.875 seconds
# Finished shard 11550000 with 50000 rows in 106.37 seconds
# Finished shard 12150000 with 50000 rows in 99.9479 seconds
# Finished shard 11500000 with 50000 rows in 107.199 seconds
# Finished shard 11900000 with 50000 rows in 102.472 seconds
# Finished shard 11950000 with 50000 rows in 103.011 seconds
# Finished shard 11850000 with 50000 rows in 103.73 seconds
# Finished shard 11400000 with 50000 rows in 110.081 seconds
# Finished shard 11700000 with 50000 rows in 106.507 seconds
# Starting shard 13000000 with 50000 rows
# Finished shard 12200000 with 50000 rows in 101.937 seconds
# Starting shard 12950000 with 50000 rows
# Starting shard 13100000 with 50000 rows
# Starting shard 13050000 with 50000 rows
# Starting shard 13150000 with 50000 rows
# Finished shard 11300000 with 50000 rows in 113.716 seconds
# Finished shard 12050000 with 50000 rows in 104.459 seconds
# Finished shard 11350000 with 50000 rows in 113.917 seconds
# Starting shard 13250000 with 50000 rows
# Starting shard 13200000 with 50000 rows
# Finished shard 12100000 with 50000 rows in 105.41 seconds
# Finished shard 11650000 with 50000 rows in 111.5 seconds
# Starting shard 13300000 with 50000 rows
# Finished shard 12000000 with 50000 rows in 106.528 seconds
# Finished shard 12300000 with 50000 rows in 103.101 seconds
# Finished shard 12250000 with 50000 rows in 104.137 seconds
# Starting shard 13350000 with 50000 rows
# Finished shard 11600000 with 50000 rows in 114.587 seconds
# Starting shard 13400000 with 50000 rows
# Finished shard 12450000 with 50000 rows in 99.6844 seconds
# Finished shard 12350000 with 50000 rows in 104.034 seconds
# Starting shard 13450000 with 50000 rows
# Starting shard 13500000 with 50000 rows
# Starting shard 13550000 with 50000 rows
# Starting shard 13600000 with 50000 rows
# Finished shard 12500000 with 50000 rows in 100.722 seconds
# Starting shard 13650000 with 50000 rows
# Starting shard 13700000 with 50000 rows
# Starting shard 13750000 with 50000 rows
# Starting shard 13800000 with 50000 rows
# Finished shard 12400000 with 50000 rows in 106.29 seconds
# Finished shard 12550000 with 50000 rows in 102.058 seconds
# Starting shard 13900000 with 50000 rows
# Starting shard 13850000 with 50000 rows
# Starting shard 13950000 with 50000 rows
# Starting shard 14000000 with 50000 rows
# Starting shard 14050000 with 50000 rows
# Finished shard 12700000 with 50000 rows in 100.713 seconds
# Starting shard 14100000 with 50000 rows
# Starting shard 14150000 with 50000 rows
# Finished shard 12750000 with 50000 rows in 101.772 seconds
# Finished shard 12600000 with 50000 rows in 104.336 seconds
# Starting shard 14200000 with 50000 rows
# Finished shard 12650000 with 50000 rows in 104.878 seconds
# Starting shard 14250000 with 50000 rows
# Starting shard 14300000 with 50000 rows
# Starting shard 14350000 with 50000 rows
# Finished shard 12850000 with 50000 rows in 99.5362 seconds
# Finished shard 12800000 with 50000 rows in 102.017 seconds
# Finished shard 12900000 with 50000 rows in 102.963 seconds
# Starting shard 14400000 with 50000 rows
# Starting shard 14450000 with 50000 rows
# Finished shard 12950000 with 50000 rows in 98.3694 seconds
# Finished shard 13000000 with 50000 rows in 99.6586 seconds
# Starting shard 14500000 with 50000 rows
# Finished shard 13050000 with 50000 rows in 102.003 seconds
# Starting shard 14550000 with 50000 rows
# Starting shard 14600000 with 50000 rows
# Finished shard 13200000 with 50000 rows in 101.891 seconds
# Finished shard 13150000 with 50000 rows in 103.631 seconds
# Finished shard 13300000 with 50000 rows in 102.77 seconds
# Starting shard 14650000 with 50000 rows
# Finished shard 13100000 with 50000 rows in 106.212 seconds
# Finished shard 13550000 with 50000 rows in 101.355 seconds
# Finished shard 13600000 with 50000 rows in 101.758 seconds
# Starting shard 14700000 with 50000 rows
# Finished shard 13250000 with 50000 rows in 106.653 seconds
# Finished shard 14000000 with 50000 rows in 98.6559 seconds
# Starting shard 14750000 with 50000 rows
# Starting shard 14800000 with 50000 rows
# Finished shard 13700000 with 50000 rows in 103.301 seconds
# Finished shard 13500000 with 50000 rows in 104.682 seconds
# Finished shard 13850000 with 50000 rows in 100.285 seconds
# Starting shard 14850000 with 50000 rows
# Starting shard 14900000 with 50000 rows
# Starting shard 14950000 with 50000 rows
# Finished shard 13400000 with 50000 rows in 107.085 seconds
# Finished shard 13800000 with 50000 rows in 102.946 seconds
# Finished shard 13350000 with 50000 rows in 108.644 seconds
# Starting shard 15000000 with 50000 rows
# Finished shard 13650000 with 50000 rows in 106.726 seconds
# Starting shard 15050000 with 50000 rows
# Finished shard 13900000 with 50000 rows in 103.833 seconds
# Starting shard 15150000 with 50000 rows
# Starting shard 15100000 with 50000 rows
# Starting shard 15200000 with 50000 rows
# Finished shard 13950000 with 50000 rows in 104.834 seconds
# Starting shard 15250000 with 50000 rows
# Starting shard 15300000 with 50000 rows
# Starting shard 15350000 with 50000 rows
# Starting shard 15400000 with 50000 rows
# Starting shard 15450000 with 50000 rows
# Finished shard 14050000 with 50000 rows in 107.504 seconds
# Starting shard 15500000 with 50000 rows
# Finished shard 13750000 with 50000 rows in 110.544 seconds
# Finished shard 14150000 with 50000 rows in 104.811 seconds
# Finished shard 14200000 with 50000 rows in 102.398 seconds
# Finished shard 14100000 with 50000 rows in 105.891 seconds
# Finished shard 14300000 with 50000 rows in 99.1385 seconds
# Finished shard 14350000 with 50000 rows in 99.1258 seconds
# Starting shard 15550000 with 50000 rows
# Finished shard 13450000 with 50000 rows in 117.016 seconds
# Starting shard 15600000 with 50000 rows
# Starting shard 15650000 with 50000 rows
# Starting shard 15700000 with 50000 rows
# Starting shard 15800000 with 50000 rows
# Starting shard 15750000 with 50000 rows
# Starting shard 15850000 with 50000 rows
# Starting shard 15900000 with 50000 rows
# Finished shard 14250000 with 50000 rows in 114.94 seconds
# Starting shard 15950000 with 50000 rows
# Finished shard 14400000 with 50000 rows in 101.8 seconds
# Finished shard 14450000 with 50000 rows in 102.839 seconds
# Finished shard 14500000 with 50000 rows in 102.152 seconds
# Starting shard 16000000 with 50000 rows
# Finished shard 14600000 with 50000 rows in 99.8263 seconds
# Finished shard 14550000 with 50000 rows in 100.415 seconds
# Starting shard 16050000 with 50000 rows
# Starting shard 16100000 with 50000 rows
# Starting shard 16150000 with 50000 rows
# Starting shard 16200000 with 50000 rows
# Finished shard 14700000 with 50000 rows in 101.36 seconds
# Finished shard 14650000 with 50000 rows in 103.725 seconds
# Finished shard 14900000 with 50000 rows in 100.677 seconds
# Starting shard 16250000 with 50000 rows
# Finished shard 15350000 with 50000 rows in 96.6491 seconds
# Starting shard 16300000 with 50000 rows
# Starting shard 16350000 with 50000 rows
# Finished shard 15200000 with 50000 rows in 101.58 seconds
# Finished shard 14750000 with 50000 rows in 106.988 seconds
# Starting shard 16400000 with 50000 rows
# Finished shard 15150000 with 50000 rows in 102.445 seconds
# Finished shard 14950000 with 50000 rows in 104.5 seconds
# Finished shard 14850000 with 50000 rows in 105.977 seconds
# Finished shard 15250000 with 50000 rows in 101.2 seconds
# Finished shard 15450000 with 50000 rows in 100.091 seconds
# Finished shard 15300000 with 50000 rows in 101.689 seconds
# Finished shard 14800000 with 50000 rows in 108.629 seconds
# Finished shard 15400000 with 50000 rows in 101.722 seconds
# Finished shard 15100000 with 50000 rows in 105.176 seconds
# Starting shard 16450000 with 50000 rows
# Finished shard 15000000 with 50000 rows in 106.682 seconds
# Starting shard 16550000 with 50000 rows
# Starting shard 16500000 with 50000 rows
# Starting shard 16600000 with 50000 rows
# Finished shard 15850000 with 50000 rows in 96.1325 seconds
# Starting shard 16650000 with 50000 rows
# Finished shard 15500000 with 50000 rows in 102.863 seconds
# Finished shard 15550000 with 50000 rows in 100.182 seconds
# Starting shard 16750000 with 50000 rows
# Starting shard 16800000 with 50000 rows
# Finished shard 15650000 with 50000 rows in 99.1554 seconds
# Finished shard 15900000 with 50000 rows in 96.8095 seconds
# Starting shard 16700000 with 50000 rows
# Finished shard 15700000 with 50000 rows in 99.1899 seconds
# Starting shard 16850000 with 50000 rows
# Finished shard 15800000 with 50000 rows in 99.8718 seconds
# Starting shard 17000000 with 50000 rows
# Starting shard 16900000 with 50000 rows
# Starting shard 17050000 with 50000 rows
# Starting shard 16950000 with 50000 rows
# Finished shard 15600000 with 50000 rows in 102.567 seconds
# Starting shard 17100000 with 50000 rows
# Starting shard 17150000 with 50000 rows
# Starting shard 17200000 with 50000 rows
# Starting shard 17250000 with 50000 rows
# Finished shard 15750000 with 50000 rows in 103.309 seconds
# Finished shard 15050000 with 50000 rows in 113.782 seconds
# Starting shard 17300000 with 50000 rows
# Starting shard 17350000 with 50000 rows
# Starting shard 17400000 with 50000 rows
# Starting shard 17500000 with 50000 rows
# Starting shard 17450000 with 50000 rows
# Finished shard 15950000 with 50000 rows in 94.5329 seconds
# Starting shard 17550000 with 50000 rows
# Finished shard 16000000 with 50000 rows in 94.6985 seconds
# Starting shard 17600000 with 50000 rows
# Finished shard 16050000 with 50000 rows in 100.909 seconds
# Finished shard 16100000 with 50000 rows in 99.3172 seconds
# Finished shard 16150000 with 50000 rows in 98.7175 seconds
# Finished shard 16200000 with 50000 rows in 98.6248 seconds
# Starting shard 17700000 with 50000 rows
# Starting shard 17650000 with 50000 rows
# Starting shard 17750000 with 50000 rows
# Finished shard 16250000 with 50000 rows in 96.6088 seconds
# Starting shard 17800000 with 50000 rows
# Starting shard 17850000 with 50000 rows
# Finished shard 16350000 with 50000 rows in 98.5062 seconds
# Finished shard 16300000 with 50000 rows in 101.321 seconds
# Finished shard 16600000 with 50000 rows in 95.8113 seconds
# Starting shard 17900000 with 50000 rows
# Finished shard 16850000 with 50000 rows in 94.4937 seconds
# Finished shard 16650000 with 50000 rows in 97.8928 seconds
# Finished shard 16750000 with 50000 rows in 97.0699 seconds
# Starting shard 17950000 with 50000 rows
# Finished shard 16800000 with 50000 rows in 97.4912 seconds
# Starting shard 18000000 with 50000 rows
# Finished shard 16400000 with 50000 rows in 104.415 seconds
# Finished shard 16900000 with 50000 rows in 97.0594 seconds
# Finished shard 16550000 with 50000 rows in 101.918 seconds
# Finished shard 16700000 with 50000 rows in 99.5366 seconds
# Starting shard 18050000 with 50000 rows
# Starting shard 18100000 with 50000 rows
# Finished shard 17100000 with 50000 rows in 96.6687 seconds
# Starting shard 18150000 with 50000 rows
# Finished shard 16450000 with 50000 rows in 103.449 seconds
# Starting shard 18200000 with 50000 rows
# Finished shard 17000000 with 50000 rows in 100.279 seconds
# Starting shard 18300000 with 50000 rows
# Starting shard 18250000 with 50000 rows
# Finished shard 16950000 with 50000 rows in 100.677 seconds
# Finished shard 17350000 with 50000 rows in 97.4562 seconds
# Starting shard 18350000 with 50000 rows
# Starting shard 18400000 with 50000 rows
# Starting shard 18450000 with 50000 rows
# Finished shard 16500000 with 50000 rows in 106.717 seconds
# Starting shard 18500000 with 50000 rows
# Finished shard 17050000 with 50000 rows in 102.759 seconds
# Finished shard 17500000 with 50000 rows in 96.6746 seconds
# Finished shard 17300000 with 50000 rows in 100.173 seconds
# Finished shard 17550000 with 50000 rows in 93.6567 seconds
# Finished shard 17150000 with 50000 rows in 101.981 seconds
# Finished shard 17250000 with 50000 rows in 101.263 seconds
# Starting shard 18550000 with 50000 rows
# Finished shard 17400000 with 50000 rows in 99.3486 seconds
# Starting shard 18600000 with 50000 rows
# Starting shard 18650000 with 50000 rows
# Finished shard 17450000 with 50000 rows in 98.8321 seconds
# Starting shard 18700000 with 50000 rows
# Starting shard 18800000 with 50000 rows
# Starting shard 18900000 with 50000 rows
# Starting shard 18750000 with 50000 rows
# Starting shard 18850000 with 50000 rows
# Starting shard 18950000 with 50000 rows
# Finished shard 17200000 with 50000 rows in 106.013 seconds
# Starting shard 19000000 with 50000 rows
# Starting shard 19050000 with 50000 rows
# Starting shard 19100000 with 50000 rows
# Starting shard 19150000 with 50000 rows
# Finished shard 17600000 with 50000 rows in 93.6672 seconds
# Starting shard 19200000 with 50000 rows
# Finished shard 17650000 with 50000 rows in 96.5176 seconds
# Finished shard 17700000 with 50000 rows in 98.6966 seconds
# Finished shard 17750000 with 50000 rows in 98.5158 seconds
# Starting shard 19250000 with 50000 rows
# Finished shard 17800000 with 50000 rows in 99.7382 seconds
# Starting shard 19300000 with 50000 rows
# Starting shard 19350000 with 50000 rows
# Finished shard 17850000 with 50000 rows in 100.407 seconds
# Starting shard 19400000 with 50000 rows
# Starting shard 19450000 with 50000 rows
# Finished shard 17900000 with 50000 rows in 103.615 seconds
# Finished shard 18350000 with 50000 rows in 95.9053 seconds
# Finished shard 18250000 with 50000 rows in 96.429 seconds
# Finished shard 18000000 with 50000 rows in 102.361 seconds
# Finished shard 18300000 with 50000 rows in 96.9976 seconds
# Finished shard 18150000 with 50000 rows in 99.4997 seconds
# Finished shard 18200000 with 50000 rows in 99.4441 seconds
# Finished shard 17950000 with 50000 rows in 104.094 seconds
# Finished shard 18050000 with 50000 rows in 102.17 seconds
# Starting shard 19500000 with 50000 rows
# Starting shard 19600000 with 50000 rows
# Starting shard 19550000 with 50000 rows
# Starting shard 19700000 with 50000 rows
# Starting shard 19650000 with 50000 rows
# Starting shard 19750000 with 50000 rows
# Starting shard 19800000 with 50000 rows
# Finished shard 18550000 with 50000 rows in 98.0727 seconds
# Finished shard 18400000 with 50000 rows in 100.805 seconds
# Starting shard 19850000 with 50000 rows
# Finished shard 18450000 with 50000 rows in 101.293 seconds
# Finished shard 18100000 with 50000 rows in 106.093 seconds
# Starting shard 19900000 with 50000 rows
# Finished shard 18900000 with 50000 rows in 98.2939 seconds
# Starting shard 20000000 with 50000 rows
# Starting shard 19950000 with 50000 rows
# Starting shard 20050000 with 50000 rows
# Starting shard 20100000 with 50000 rows
# Finished shard 18850000 with 50000 rows in 100.7 seconds
# Starting shard 20150000 with 50000 rows
# Finished shard 18700000 with 50000 rows in 102.963 seconds
# Finished shard 18500000 with 50000 rows in 107.39 seconds
# Finished shard 18600000 with 50000 rows in 105.093 seconds
# Finished shard 18750000 with 50000 rows in 103.088 seconds
# Finished shard 18650000 with 50000 rows in 105.523 seconds
# Starting shard 20200000 with 50000 rows
# Finished shard 18800000 with 50000 rows in 104.581 seconds
# Finished shard 19050000 with 50000 rows in 102.512 seconds
# Starting shard 20300000 with 50000 rows
# Starting shard 20250000 with 50000 rows
# Starting shard 20400000 with 50000 rows
# Starting shard 20350000 with 50000 rows
# Starting shard 20450000 with 50000 rows
# Starting shard 20500000 with 50000 rows
# Starting shard 20550000 with 50000 rows
# Finished shard 18950000 with 50000 rows in 108.474 seconds
# Finished shard 19150000 with 50000 rows in 104.433 seconds
# Finished shard 19000000 with 50000 rows in 109.508 seconds
# Finished shard 19100000 with 50000 rows in 107.596 seconds
# Starting shard 20600000 with 50000 rows
# Starting shard 20650000 with 50000 rows
# Starting shard 20700000 with 50000 rows
# Starting shard 20750000 with 50000 rows
# Finished shard 19200000 with 50000 rows in 98.8153 seconds
# Starting shard 20800000 with 50000 rows
# Finished shard 19250000 with 50000 rows in 99.0817 seconds
# Finished shard 19350000 with 50000 rows in 98.7999 seconds
# Starting shard 20850000 with 50000 rows
# Finished shard 19450000 with 50000 rows in 94.9976 seconds
# Finished shard 19400000 with 50000 rows in 98.2543 seconds
# Starting shard 20900000 with 50000 rows
# Starting shard 20950000 with 50000 rows
# Starting shard 21000000 with 50000 rows
# Finished shard 19300000 with 50000 rows in 106.423 seconds
# Starting shard 21050000 with 50000 rows
# Finished shard 19700000 with 50000 rows in 97.0294 seconds
# Finished shard 19550000 with 50000 rows in 97.8498 seconds
# Finished shard 19650000 with 50000 rows in 98.0828 seconds
# Finished shard 19500000 with 50000 rows in 100.061 seconds
# Finished shard 19900000 with 50000 rows in 97.3636 seconds
# Finished shard 19750000 with 50000 rows in 100.267 seconds
# Starting shard 21100000 with 50000 rows
# Starting shard 21150000 with 50000 rows
# Starting shard 21200000 with 50000 rows
# Starting shard 21250000 with 50000 rows
# Finished shard 20100000 with 50000 rows in 96.8249 seconds
# Finished shard 19600000 with 50000 rows in 103.922 seconds
# Starting shard 21350000 with 50000 rows
# Finished shard 20150000 with 50000 rows in 96.571 seconds
# Starting shard 21300000 with 50000 rows
# Finished shard 19800000 with 50000 rows in 103.591 seconds
# Finished shard 20050000 with 50000 rows in 99.2418 seconds
# Starting shard 21400000 with 50000 rows
# Finished shard 20000000 with 50000 rows in 102.724 seconds
# Starting shard 21450000 with 50000 rows
# Starting shard 21550000 with 50000 rows
# Finished shard 19950000 with 50000 rows in 103.114 seconds
# Starting shard 21500000 with 50000 rows
# Starting shard 21600000 with 50000 rows
# Finished shard 19850000 with 50000 rows in 108.87 seconds
# Finished shard 20400000 with 50000 rows in 98.3016 seconds
# Finished shard 20200000 with 50000 rows in 101.964 seconds
# Finished shard 20350000 with 50000 rows in 99.1263 seconds
# Starting shard 21700000 with 50000 rows
# Starting shard 21650000 with 50000 rows
# Finished shard 20450000 with 50000 rows in 98.8164 seconds
# Finished shard 20550000 with 50000 rows in 98.882 seconds
# Finished shard 20250000 with 50000 rows in 101.131 seconds
# Starting shard 21750000 with 50000 rows
# Starting shard 21800000 with 50000 rows
# Starting shard 21900000 with 50000 rows
# Starting shard 21850000 with 50000 rows
# Starting shard 21950000 with 50000 rows
# Finished shard 20500000 with 50000 rows in 102.67 seconds
# Starting shard 22000000 with 50000 rows
# Starting shard 22050000 with 50000 rows
# Finished shard 20300000 with 50000 rows in 105.292 seconds
# Finished shard 20600000 with 50000 rows in 99.9572 seconds
# Starting shard 22100000 with 50000 rows
# Finished shard 20700000 with 50000 rows in 100.328 seconds
# Starting shard 22150000 with 50000 rows
# Starting shard 22200000 with 50000 rows
# Starting shard 22250000 with 50000 rows
# Finished shard 20650000 with 50000 rows in 106.774 seconds
# Finished shard 20750000 with 50000 rows in 107.442 seconds
# Starting shard 22300000 with 50000 rows
# Starting shard 22350000 with 50000 rows
# Finished shard 20800000 with 50000 rows in 104.204 seconds
# Starting shard 22400000 with 50000 rows
# Finished shard 20900000 with 50000 rows in 97.1139 seconds
# Finished shard 20950000 with 50000 rows in 97.5204 seconds
# Finished shard 21000000 with 50000 rows in 98.564 seconds
# Starting shard 22450000 with 50000 rows
# Starting shard 22500000 with 50000 rows
# Starting shard 22550000 with 50000 rows
# Finished shard 20850000 with 50000 rows in 106.538 seconds
# Starting shard 22600000 with 50000 rows
# Finished shard 21050000 with 50000 rows in 103.921 seconds
# Finished shard 21150000 with 50000 rows in 97.6978 seconds
# Starting shard 22700000 with 50000 rows
# Starting shard 22650000 with 50000 rows
# Finished shard 21200000 with 50000 rows in 101.104 seconds
# Finished shard 21100000 with 50000 rows in 103.237 seconds
# Finished shard 21250000 with 50000 rows in 102.292 seconds
# Finished shard 21350000 with 50000 rows in 101.241 seconds
# Finished shard 21400000 with 50000 rows in 99.1042 seconds
# Finished shard 21500000 with 50000 rows in 98.272 seconds
# Finished shard 21450000 with 50000 rows in 99.46 seconds
# Starting shard 22750000 with 50000 rows
# Finished shard 21550000 with 50000 rows in 100.229 seconds
# Starting shard 22800000 with 50000 rows
# Starting shard 22850000 with 50000 rows
# Starting shard 22950000 with 50000 rows
# Starting shard 22900000 with 50000 rows
# Finished shard 21300000 with 50000 rows in 105.71 seconds
# Starting shard 23000000 with 50000 rows
# Starting shard 23100000 with 50000 rows
# Starting shard 23050000 with 50000 rows
# Starting shard 23150000 with 50000 rows
# Finished shard 21800000 with 50000 rows in 99.152 seconds
# Finished shard 21700000 with 50000 rows in 102.757 seconds
# Finished shard 21650000 with 50000 rows in 102.891 seconds
# Finished shard 22000000 with 50000 rows in 98.9065 seconds
# Finished shard 22050000 with 50000 rows in 99.6871 seconds
# Finished shard 21950000 with 50000 rows in 101.444 seconds
# Starting shard 23200000 with 50000 rows
# Finished shard 22150000 with 50000 rows in 96.8547 seconds
# Starting shard 23300000 with 50000 rows
# Starting shard 23250000 with 50000 rows
# Finished shard 21750000 with 50000 rows in 104.815 seconds
# Finished shard 21850000 with 50000 rows in 103.175 seconds
# Starting shard 23350000 with 50000 rows
# Finished shard 21900000 with 50000 rows in 104.652 seconds
# Starting shard 23400000 with 50000 rows
# Starting shard 23450000 with 50000 rows
# Finished shard 22100000 with 50000 rows in 101.735 seconds
# Starting shard 23500000 with 50000 rows
# Starting shard 23550000 with 50000 rows
# Starting shard 23600000 with 50000 rows
# Finished shard 21600000 with 50000 rows in 114.316 seconds
# Starting shard 23650000 with 50000 rows
# Finished shard 22200000 with 50000 rows in 103.14 seconds
# Starting shard 23700000 with 50000 rows
# Starting shard 23750000 with 50000 rows
# Starting shard 23800000 with 50000 rows
# Finished shard 22250000 with 50000 rows in 104.28 seconds
# Finished shard 22300000 with 50000 rows in 101.119 seconds
# Starting shard 23850000 with 50000 rows
# Finished shard 22350000 with 50000 rows in 102.853 seconds
# Starting shard 23900000 with 50000 rows
# Starting shard 23950000 with 50000 rows
# Finished shard 22400000 with 50000 rows in 102.568 seconds
# Finished shard 22500000 with 50000 rows in 98.4115 seconds
# Starting shard 24000000 with 50000 rows
# Finished shard 22550000 with 50000 rows in 100.031 seconds
# Starting shard 24050000 with 50000 rows
# Starting shard 24100000 with 50000 rows
# Finished shard 22600000 with 50000 rows in 99.9887 seconds
# Finished shard 22450000 with 50000 rows in 108.046 seconds
# Starting shard 24150000 with 50000 rows
# Starting shard 24200000 with 50000 rows
# Finished shard 22750000 with 50000 rows in 97.7862 seconds
# Finished shard 22700000 with 50000 rows in 102.961 seconds
# Finished shard 22650000 with 50000 rows in 103.822 seconds
# Finished shard 22800000 with 50000 rows in 99.7818 seconds
# Finished shard 23150000 with 50000 rows in 95.137 seconds
# Starting shard 24250000 with 50000 rows
# Starting shard 24300000 with 50000 rows
# Starting shard 24350000 with 50000 rows
# Finished shard 22950000 with 50000 rows in 101.467 seconds
# Finished shard 22900000 with 50000 rows in 101.738 seconds
# Finished shard 22850000 with 50000 rows in 102.081 seconds
# Starting shard 24400000 with 50000 rows
# Starting shard 24450000 with 50000 rows
# Finished shard 23000000 with 50000 rows in 102.195 seconds
# Starting shard 24500000 with 50000 rows
# Finished shard 23100000 with 50000 rows in 102.662 seconds
# Finished shard 23050000 with 50000 rows in 103.163 seconds
# Starting shard 24600000 with 50000 rows
# Starting shard 24550000 with 50000 rows
# Starting shard 24650000 with 50000 rows
# Finished shard 23300000 with 50000 rows in 99.645 seconds
# Starting shard 24700000 with 50000 rows
# Finished shard 23200000 with 50000 rows in 100.298 seconds
# Finished shard 23250000 with 50000 rows in 99.9015 seconds
# Finished shard 23350000 with 50000 rows in 98.5033 seconds
# Starting shard 24750000 with 50000 rows
# Finished shard 23500000 with 50000 rows in 98.2076 seconds
# Finished shard 23400000 with 50000 rows in 99.2404 seconds
# Finished shard 23600000 with 50000 rows in 97.61 seconds
# Finished shard 23450000 with 50000 rows in 100.144 seconds
# Starting shard 24850000 with 50000 rows
# Starting shard 24800000 with 50000 rows
# Starting shard 24900000 with 50000 rows
# Starting shard 24950000 with 50000 rows
# Finished shard 23750000 with 50000 rows in 96.142 seconds
# Finished shard 23550000 with 50000 rows in 100.95 seconds
# Finished shard 23650000 with 50000 rows in 100.222 seconds
# Starting shard 25000000 with 50000 rows
# Starting shard 25100000 with 50000 rows
# Starting shard 25050000 with 50000 rows
# Starting shard 25150000 with 50000 rows
# Starting shard 25200000 with 50000 rows
# Starting shard 25250000 with 50000 rows
# Starting shard 25300000 with 50000 rows
# Finished shard 23700000 with 50000 rows in 101.829 seconds
# Starting shard 25350000 with 50000 rows
# ...
# Starting shard 99600000 with 50000 rows
# Finished shard 98050000 with 50000 rows in 100.464 seconds
# Starting shard 99650000 with 50000 rows
# Starting shard 99700000 with 50000 rows
# Finished shard 98150000 with 50000 rows in 102.997 seconds
# Starting shard 99750000 with 50000 rows
# Finished shard 98200000 with 50000 rows in 107.403 seconds
# Starting shard 99800000 with 50000 rows
# Finished shard 98250000 with 50000 rows in 116.046 seconds
# Starting shard 99850000 with 50000 rows
# Finished shard 98300000 with 50000 rows in 108.673 seconds
# Finished shard 98400000 with 50000 rows in 105.473 seconds
# Starting shard 99900000 with 50000 rows
# Finished shard 98500000 with 50000 rows in 108.019 seconds
# Starting shard 99950000 with 50000 rows
# Finished shard 98350000 with 50000 rows in 112.733 seconds
# Finished shard 98550000 with 50000 rows in 106.99 seconds
# Finished shard 98450000 with 50000 rows in 111.451 seconds
# Starting shard 100000000 with 50000 rows
# Finished shard 98650000 with 50000 rows in 107.67 seconds
# Starting shard 100050000 with 50000 rows
# Starting shard 100100000 with 50000 rows
# Finished shard 98700000 with 50000 rows in 106.725 seconds
# Finished shard 98600000 with 50000 rows in 110.523 seconds
# Starting shard 100150000 with 50000 rows
# Starting shard 100200000 with 50000 rows
# Finished shard 98750000 with 50000 rows in 108.606 seconds
# Starting shard 100300000 with 50000 rows
# Starting shard 100250000 with 50000 rows
# Starting shard 100350000 with 50000 rows
# Finished shard 98850000 with 50000 rows in 108.7 seconds
# Finished shard 98800000 with 50000 rows in 111.632 seconds
# Finished shard 98900000 with 50000 rows in 109.992 seconds
# Starting shard 100400000 with 50000 rows
# Starting shard 100450000 with 50000 rows
# Starting shard 100500000 with 50000 rows
# Finished shard 98950000 with 50000 rows in 110.381 seconds
# Starting shard 100550000 with 50000 rows
# Finished shard 99250000 with 50000 rows in 103.193 seconds
# Finished shard 99000000 with 50000 rows in 113.827 seconds
# Starting shard 100600000 with 50000 rows
# Finished shard 99150000 with 50000 rows in 111.311 seconds
# Starting shard 100650000 with 50000 rows
# Finished shard 99050000 with 50000 rows in 116.041 seconds
# Finished shard 99100000 with 50000 rows in 113.589 seconds
# Finished shard 99200000 with 50000 rows in 113.059 seconds
# Starting shard 100700000 with 50000 rows
# Starting shard 100800000 with 50000 rows
# Finished shard 99450000 with 50000 rows in 97.9278 seconds
# Starting shard 100750000 with 50000 rows
# Starting shard 100850000 with 50000 rows
# Starting shard 100900000 with 50000 rows
# Finished shard 99400000 with 50000 rows in 104.937 seconds
# Starting shard 100950000 with 50000 rows
# Finished shard 99300000 with 50000 rows in 120.404 seconds
# Finished shard 99500000 with 50000 rows in 104.855 seconds
# Starting shard 101000000 with 50000 rows
# Starting shard 101050000 with 50000 rows
# Finished shard 99550000 with 50000 rows in 102.397 seconds
# Finished shard 99350000 with 50000 rows in 122.39 seconds
# Starting shard 101100000 with 50000 rows
# Starting shard 101150000 with 50000 rows
# Finished shard 99600000 with 50000 rows in 105.967 seconds
# Finished shard 99650000 with 50000 rows in 104.372 seconds
# Finished shard 99750000 with 50000 rows in 99.5895 seconds
# Finished shard 99700000 with 50000 rows in 105.532 seconds
# Starting shard 101200000 with 50000 rows
# Starting shard 101250000 with 50000 rows
# Starting shard 101300000 with 50000 rows
# Starting shard 101350000 with 50000 rows
# Finished shard 99800000 with 50000 rows in 104.846 seconds
# Starting shard 101400000 with 50000 rows
# Finished shard 99850000 with 50000 rows in 106.67 seconds
# Starting shard 101450000 with 50000 rows
# Finished shard 100150000 with 50000 rows in 99.7018 seconds
# Starting shard 101500000 with 50000 rows
# Finished shard 100250000 with 50000 rows in 101.093 seconds
# Finished shard 99950000 with 50000 rows in 112.134 seconds
# Finished shard 99900000 with 50000 rows in 114.526 seconds
# Starting shard 101550000 with 50000 rows
# Finished shard 100100000 with 50000 rows in 108.703 seconds
# Finished shard 100300000 with 50000 rows in 104.959 seconds
# Starting shard 101600000 with 50000 rows
# Finished shard 100000000 with 50000 rows in 111.719 seconds
# Starting shard 101650000 with 50000 rows
# Starting shard 101700000 with 50000 rows
# Starting shard 101800000 with 50000 rows
# Starting shard 101750000 with 50000 rows
# Finished shard 100200000 with 50000 rows in 113.896 seconds
# Finished shard 100350000 with 50000 rows in 110.646 seconds
# Starting shard 101850000 with 50000 rows
# Finished shard 100400000 with 50000 rows in 103.463 seconds
# Starting shard 101900000 with 50000 rows
# Starting shard 101950000 with 50000 rows
# Finished shard 100450000 with 50000 rows in 108.475 seconds
# Starting shard 102000000 with 50000 rows
# Finished shard 100500000 with 50000 rows in 112.361 seconds
# Starting shard 102050000 with 50000 rows
# Finished shard 100600000 with 50000 rows in 106.805 seconds
# Finished shard 100050000 with 50000 rows in 134.826 seconds
# Finished shard 100550000 with 50000 rows in 110.993 seconds
# Finished shard 100900000 with 50000 rows in 97.5507 seconds
# Starting shard 102150000 with 50000 rows
# Starting shard 102100000 with 50000 rows
# Starting shard 102250000 with 50000 rows
# Starting shard 102200000 with 50000 rows
# Finished shard 100800000 with 50000 rows in 108.097 seconds
# Finished shard 100650000 with 50000 rows in 112.601 seconds
# Finished shard 100850000 with 50000 rows in 108.235 seconds
# Finished shard 100700000 with 50000 rows in 110.944 seconds
# Starting shard 102300000 with 50000 rows
# Finished shard 100750000 with 50000 rows in 111.346 seconds
# Starting shard 102350000 with 50000 rows
# Starting shard 102400000 with 50000 rows
# Starting shard 102450000 with 50000 rows
# Starting shard 102500000 with 50000 rows
# Finished shard 101000000 with 50000 rows in 105.777 seconds
# Finished shard 101100000 with 50000 rows in 99.8907 seconds
# Finished shard 101150000 with 50000 rows in 99.647 seconds
# Starting shard 102550000 with 50000 rows
# Finished shard 100950000 with 50000 rows in 114.102 seconds
# Starting shard 102600000 with 50000 rows
# Starting shard 102650000 with 50000 rows
# Finished shard 101050000 with 50000 rows in 111.09 seconds
# Starting shard 102700000 with 50000 rows
# Finished shard 101300000 with 50000 rows in 97.5359 seconds
# Starting shard 102750000 with 50000 rows
# Finished shard 101250000 with 50000 rows in 100.462 seconds
# Starting shard 102800000 with 50000 rows
# Finished shard 101350000 with 50000 rows in 99.5073 seconds
# Starting shard 102850000 with 50000 rows
# Starting shard 102900000 with 50000 rows
# Finished shard 101200000 with 50000 rows in 110.613 seconds
# Starting shard 102950000 with 50000 rows
# Finished shard 101400000 with 50000 rows in 102.846 seconds
# Starting shard 103000000 with 50000 rows
# Finished shard 101450000 with 50000 rows in 113.644 seconds
# Starting shard 103050000 with 50000 rows
# Finished shard 101650000 with 50000 rows in 95.5765 seconds
# Starting shard 103100000 with 50000 rows
# Finished shard 101550000 with 50000 rows in 100.778 seconds
# Finished shard 101500000 with 50000 rows in 105.349 seconds
# Starting shard 103150000 with 50000 rows
# Finished shard 101700000 with 50000 rows in 100.005 seconds
# Starting shard 103200000 with 50000 rows
# Starting shard 103250000 with 50000 rows
# Finished shard 101600000 with 50000 rows in 113.395 seconds
# Starting shard 103300000 with 50000 rows
# Finished shard 101750000 with 50000 rows in 116.923 seconds
# Starting shard 103350000 with 50000 rows
# Finished shard 101850000 with 50000 rows in 115.857 seconds
# Finished shard 101800000 with 50000 rows in 124.432 seconds
# Starting shard 103400000 with 50000 rows
# Finished shard 101950000 with 50000 rows in 115.589 seconds
# Starting shard 103450000 with 50000 rows
# Finished shard 102000000 with 50000 rows in 112.149 seconds
# Finished shard 102100000 with 50000 rows in 103.729 seconds
# Starting shard 103500000 with 50000 rows
# Finished shard 101900000 with 50000 rows in 122.151 seconds
# Starting shard 103550000 with 50000 rows
# Starting shard 103600000 with 50000 rows
# Starting shard 103650000 with 50000 rows
# Finished shard 102050000 with 50000 rows in 114.989 seconds
# Finished shard 102250000 with 50000 rows in 110.445 seconds
# Finished shard 102200000 with 50000 rows in 110.084 seconds
# Starting shard 103700000 with 50000 rows
# Finished shard 102150000 with 50000 rows in 113.389 seconds
# Starting shard 103750000 with 50000 rows
# Starting shard 103800000 with 50000 rows
# Starting shard 103850000 with 50000 rows
# Finished shard 102300000 with 50000 rows in 112.811 seconds
# Finished shard 102400000 with 50000 rows in 113.239 seconds
# Starting shard 103900000 with 50000 rows
# Starting shard 103950000 with 50000 rows
# Finished shard 102450000 with 50000 rows in 117.396 seconds
# Finished shard 102850000 with 50000 rows in 100.5 seconds
# Finished shard 102650000 with 50000 rows in 109.531 seconds
# Starting shard 104000000 with 50000 rows
# Starting shard 104050000 with 50000 rows
# Starting shard 104100000 with 50000 rows
# Finished shard 102900000 with 50000 rows in 103.449 seconds
# Finished shard 102350000 with 50000 rows in 123.747 seconds
# Finished shard 102500000 with 50000 rows in 121.464 seconds
# Starting shard 104150000 with 50000 rows
# Finished shard 102600000 with 50000 rows in 115.786 seconds
# Starting shard 104200000 with 50000 rows
# Starting shard 104250000 with 50000 rows
# Starting shard 104300000 with 50000 rows
# Finished shard 102800000 with 50000 rows in 111.995 seconds
# Starting shard 104350000 with 50000 rows
# Finished shard 102700000 with 50000 rows in 124.234 seconds
# Finished shard 102550000 with 50000 rows in 130.262 seconds
# Starting shard 104400000 with 50000 rows
# Starting shard 104450000 with 50000 rows
# Finished shard 102950000 with 50000 rows in 118.718 seconds
# Finished shard 103000000 with 50000 rows in 115.861 seconds
# Starting shard 104500000 with 50000 rows
# Starting shard 104550000 with 50000 rows
# Finished shard 103100000 with 50000 rows in 91.7115 seconds
# Starting shard 104600000 with 50000 rows
# Finished shard 103150000 with 50000 rows in 94.0226 seconds
# Starting shard 104650000 with 50000 rows
# Finished shard 103050000 with 50000 rows in 106.8 seconds
# Finished shard 102750000 with 50000 rows in 147.537 seconds
# Finished shard 103200000 with 50000 rows in 99.709 seconds
# Finished shard 103250000 with 50000 rows in 97.4543 seconds
# Starting shard 104700000 with 50000 rows
# Starting shard 104750000 with 50000 rows
# Starting shard 104800000 with 50000 rows
# Starting shard 104850000 with 50000 rows
# Finished shard 103300000 with 50000 rows in 104.428 seconds
# Starting shard 104900000 with 50000 rows
# Finished shard 103350000 with 50000 rows in 103.503 seconds
# Starting shard 104950000 with 50000 rows
# Finished shard 103700000 with 50000 rows in 96.8207 seconds
# Finished shard 103950000 with 50000 rows in 85.4347 seconds
# Starting shard 105000000 with 50000 rows
# Finished shard 103450000 with 50000 rows in 109.93 seconds
# Starting shard 105050000 with 50000 rows
# Finished shard 103400000 with 50000 rows in 113.163 seconds
# Finished shard 104000000 with 50000 rows in 83.9905 seconds
# Finished shard 103500000 with 50000 rows in 110.661 seconds
# Starting shard 105100000 with 50000 rows
# Finished shard 103750000 with 50000 rows in 102.345 seconds
# Starting shard 105150000 with 50000 rows
# Finished shard 103550000 with 50000 rows in 110.286 seconds
# Starting shard 105200000 with 50000 rows
# Starting shard 105250000 with 50000 rows
# Starting shard 105300000 with 50000 rows
# Finished shard 104150000 with 50000 rows in 83.172 seconds
# Finished shard 104100000 with 50000 rows in 87.1081 seconds
# Starting shard 105350000 with 50000 rows
# Finished shard 103600000 with 50000 rows in 111.642 seconds
# Starting shard 105400000 with 50000 rows
# Finished shard 103800000 with 50000 rows in 107.012 seconds
# Starting shard 105450000 with 50000 rows
# Starting shard 105550000 with 50000 rows
# Starting shard 105500000 with 50000 rows
# Finished shard 104050000 with 50000 rows in 94.1665 seconds
# Finished shard 104300000 with 50000 rows in 90.1996 seconds
# Starting shard 105600000 with 50000 rows
# Starting shard 105650000 with 50000 rows
# Finished shard 103650000 with 50000 rows in 120.057 seconds
# Starting shard 105700000 with 50000 rows
# Finished shard 103900000 with 50000 rows in 110.429 seconds
# Finished shard 104250000 with 50000 rows in 97.3932 seconds
# Finished shard 103850000 with 50000 rows in 118.489 seconds
# Starting shard 105800000 with 50000 rows
# Starting shard 105750000 with 50000 rows
# Starting shard 105850000 with 50000 rows
# Finished shard 104200000 with 50000 rows in 116.747 seconds
# Finished shard 104350000 with 50000 rows in 115.28 seconds
# Finished shard 104450000 with 50000 rows in 103.987 seconds
# Starting shard 105900000 with 50000 rows
# Finished shard 104400000 with 50000 rows in 107.472 seconds
# Starting shard 105950000 with 50000 rows
# Starting shard 106000000 with 50000 rows
# Starting shard 106050000 with 50000 rows
# Finished shard 104650000 with 50000 rows in 90.6221 seconds
# Starting shard 106100000 with 50000 rows
# Finished shard 104550000 with 50000 rows in 102.054 seconds
# Finished shard 104800000 with 50000 rows in 88.4799 seconds
# Starting shard 106150000 with 50000 rows
# Finished shard 104850000 with 50000 rows in 89.2669 seconds
# Starting shard 106200000 with 50000 rows
# Finished shard 104750000 with 50000 rows in 93.0927 seconds
# Starting shard 106250000 with 50000 rows
# Starting shard 106300000 with 50000 rows
# Finished shard 104700000 with 50000 rows in 100.758 seconds
# Finished shard 104500000 with 50000 rows in 115.686 seconds
# Starting shard 106350000 with 50000 rows
# Starting shard 106400000 with 50000 rows
# Finished shard 104600000 with 50000 rows in 120.901 seconds
# Finished shard 104950000 with 50000 rows in 86.5943 seconds
# Finished shard 104900000 with 50000 rows in 94.5549 seconds
# Starting shard 106450000 with 50000 rows
# Starting shard 106500000 with 50000 rows
# Starting shard 106550000 with 50000 rows
# Finished shard 105050000 with 50000 rows in 84.6705 seconds
# Starting shard 106600000 with 5365 rows
# Finished shard 105300000 with 50000 rows in 80.5671 seconds
# Finished shard 105200000 with 50000 rows in 83.276 seconds
# Finished shard 105150000 with 50000 rows in 84.158 seconds
# Finished shard 105100000 with 50000 rows in 85.6078 seconds
# Finished shard 105250000 with 50000 rows in 85.8855 seconds
# Finished shard 106600000 with 5365 rows in 8.51245 seconds
# Finished shard 105400000 with 50000 rows in 86.8249 seconds
# Finished shard 105350000 with 50000 rows in 88.0874 seconds
# Finished shard 105000000 with 50000 rows in 96.305 seconds
# Finished shard 105450000 with 50000 rows in 88.3407 seconds
# Finished shard 105600000 with 50000 rows in 86.2266 seconds
# Finished shard 105550000 with 50000 rows in 93.825 seconds
# Finished shard 105700000 with 50000 rows in 85.7361 seconds
# Finished shard 105500000 with 50000 rows in 94.3735 seconds
# Finished shard 105650000 with 50000 rows in 90.0266 seconds
# Finished shard 105850000 with 50000 rows in 83.5797 seconds
# Finished shard 105800000 with 50000 rows in 85.3425 seconds
# Finished shard 105750000 with 50000 rows in 85.0502 seconds
# Finished shard 106000000 with 50000 rows in 73.525 seconds
# Finished shard 105900000 with 50000 rows in 77.635 seconds
# Finished shard 105950000 with 50000 rows in 76.6541 seconds
# Finished shard 106050000 with 50000 rows in 76.079 seconds
# Finished shard 106250000 with 50000 rows in 68.3003 seconds
# Finished shard 106200000 with 50000 rows in 72.476 seconds
# Finished shard 106100000 with 50000 rows in 81.6109 seconds
# Finished shard 106150000 with 50000 rows in 81.0791 seconds
# Finished shard 106350000 with 50000 rows in 76.6483 seconds
# Finished shard 106550000 with 50000 rows in 65.3405 seconds
# Finished shard 106400000 with 50000 rows in 77.7639 seconds
# Finished shard 106450000 with 50000 rows in 68.7912 seconds
# Finished shard 106300000 with 50000 rows in 88.0411 seconds
# Finished shard 106500000 with 50000 rows in 72.1125 seconds

# %%
record_len = 6 * 4
print '%s has %.1f records (points)' % (dest, os.stat(dest).st_size / float(record_len))
# Out:
# od-JT01-2011.bin has 120322051.0 records (points)

# %% [markdown]
# Compute dot home location for "non-employed" persons
# ----------------------------------------------------
#
# Compute non-employed persons by subtracting LODES primary jobs from "working age population" (15-64) from 2010 Decennial census

# %%
def get_geocode_at(idx):
    q = "SELECT geocode FROM working_age_blocks ORDER BY geocode OFFSET {idx} LIMIT 1 ".format(idx=idx)
    return query_psql(q, quiet=True)[0][0]

def process_nonemployment_shard(shard_start, shard_end):
    query = (
            "SELECT MIN(h.geom), MIN(t.working_age_pop), "
            "SUM(od.se01 + od.se02 + od.se03)"
            "FROM working_age_blocks t "
            "JOIN tl_2010_tabblock10 h ON t.geocode = h.geoid10 "
            "LEFT JOIN od_{jt}_{year} od ON t.geocode = od.h_geocode "
            "WHERE t.geocode BETWEEN '{geocode_start}' AND '{geocode_end}' "
            #"AND t.geocode LIKE '42%' "
            "GROUP BY t.geocode "
            ).format(jt=jt, year=year, geocode_start=get_geocode_at(shard_start), geocode_end=get_geocode_at(shard_end))
    rows = query_psql_throttled(query, quiet=True)
    begin_time = time.time()
    if len(rows) == 0:
        sys.stdout.write("No rows, aborting nonemployment shard %d\n" % shard_start)
        return []
    sys.stdout.write("Starting nonemployment shard %d with %d rows\n" % (shard_start, len(rows)))

    points = []
    pcolor = pack_color(nonemployed_color)
    for (homeGeom, working_age_pop, employed_pop) in rows:
        if employed_pop == None:
            # LODES records no employment for this home block
            employed_pop = 0
        homePolygon = shapely.wkb.loads(homeGeom, hex=True)

        dist = 0
        count = max(working_age_pop - employed_pop, 0)
        # TODO:  look at negative values;  maybe show them as a different color until we better understand
        for i in range(count):
            hpoint = LonLatToPixelXY(randomPoint(homePolygon))
            points.append(struct.pack('<ffffff', hpoint[0], hpoint[1], hpoint[0], hpoint[1], dist, pcolor))
        
        if len(points) >= 10000:
            write_points(points)
            points = []
    write_points(points)
    sys.stdout.write("Finished nonemployment shard %d with %d rows in %g seconds\n" % (shard_start, len(rows), time.time() - begin_time))

# %%
max_shard_idx = query_psql("SELECT COUNT(*) FROM working_age_blocks", quiet=True)[0][0] - 1

shard_size = 50000

pool = multiprocessing.Pool()


print "Starting shards with maximum index %d" % max_shard_idx

results = []
for shard_start in range(0, max_shard_idx + 1, shard_size):
    results.append(pool.apply_async(process_nonemployment_shard, (shard_start, min(max_shard_idx, shard_start + shard_size - 1))))

print "No more shards to create.  Waiting for shards to finish."

pool.close()
pool.join()

for res in results:
    res.get()
# Out:
# Starting shards with maximum index 11155485
# No more shards to create.  Waiting for shards to finish.
# Starting nonemployment shard 300000 with 50000 rows
# Starting nonemployment shard 100000 with 50000 rows
# Starting nonemployment shard 150000 with 50000 rows
# Starting nonemployment shard 200000 with 50000 rows
# Starting nonemployment shard 450000 with 50000 rows
# Starting nonemployment shard 400000 with 50000 rows
# Starting nonemployment shard 550000 with 50000 rows
# Starting nonemployment shard 600000 with 50000 rows
# Finished nonemployment shard 300000 with 50000 rows in 44.5443 seconds
# Starting nonemployment shard 50000 with 50000 rows
# Starting nonemployment shard 650000 with 50000 rows
# Starting nonemployment shard 0 with 50000 rows
# Starting nonemployment shard 500000 with 50000 rows
# Starting nonemployment shard 250000 with 50000 rows
# Starting nonemployment shard 350000 with 50000 rows
# Starting nonemployment shard 850000 with 50000 rows
# Finished nonemployment shard 600000 with 50000 rows in 69.5655 seconds
# Starting nonemployment shard 700000 with 50000 rows
# Starting nonemployment shard 750000 with 50000 rows
# Starting nonemployment shard 1350000 with 50000 rows
# Starting nonemployment shard 900000 with 50000 rows
# Starting nonemployment shard 1200000 with 50000 rows
# Starting nonemployment shard 1050000 with 50000 rows
# Finished nonemployment shard 550000 with 50000 rows in 92.2877 seconds
# Starting nonemployment shard 950000 with 50000 rows
# Finished nonemployment shard 200000 with 50000 rows in 127.311 seconds
# Finished nonemployment shard 150000 with 50000 rows in 139.238 seconds
# Finished nonemployment shard 100000 with 50000 rows in 151.647 seconds
# Starting nonemployment shard 800000 with 50000 rows
# Starting nonemployment shard 1000000 with 50000 rows
# Finished nonemployment shard 450000 with 50000 rows in 152.543 seconds
# Finished nonemployment shard 650000 with 50000 rows in 107.57 seconds
# Finished nonemployment shard 50000 with 50000 rows in 114.141 seconds
# Starting nonemployment shard 1300000 with 50000 rows
# Starting nonemployment shard 1150000 with 50000 rows
# Starting nonemployment shard 1250000 with 50000 rows
# Starting nonemployment shard 1550000 with 50000 rows
# Starting nonemployment shard 1400000 with 50000 rows
# Starting nonemployment shard 1100000 with 50000 rows
# Starting nonemployment shard 1500000 with 50000 rows
# Starting nonemployment shard 1450000 with 50000 rows
# Starting nonemployment shard 1600000 with 50000 rows
# Starting nonemployment shard 1800000 with 50000 rows
# Starting nonemployment shard 1750000 with 50000 rows
# Starting nonemployment shard 1650000 with 50000 rows
# Finished nonemployment shard 500000 with 50000 rows in 121.222 seconds
# Starting nonemployment shard 2000000 with 50000 rows
# Finished nonemployment shard 250000 with 50000 rows in 155.874 seconds
# Finished nonemployment shard 0 with 50000 rows in 167.429 seconds
# Starting nonemployment shard 1900000 with 50000 rows
# Starting nonemployment shard 1850000 with 50000 rows
# Starting nonemployment shard 2100000 with 50000 rows
# Starting nonemployment shard 1700000 with 50000 rows
# Starting nonemployment shard 2150000 with 50000 rows
# Starting nonemployment shard 1950000 with 50000 rows
# Starting nonemployment shard 2050000 with 50000 rows
# Finished nonemployment shard 400000 with 50000 rows in 313.354 seconds
# Finished nonemployment shard 1550000 with 50000 rows in 149.649 seconds
# Starting nonemployment shard 2250000 with 50000 rows
# Finished nonemployment shard 800000 with 50000 rows in 203.213 seconds
# Finished nonemployment shard 350000 with 50000 rows in 283.345 seconds
# Starting nonemployment shard 2350000 with 50000 rows
# Starting nonemployment shard 2200000 with 50000 rows
# Finished nonemployment shard 1600000 with 50000 rows in 240.118 seconds
# Finished nonemployment shard 1350000 with 50000 rows in 345.654 seconds
# Finished nonemployment shard 700000 with 50000 rows in 349.982 seconds
# Starting nonemployment shard 2300000 with 50000 rows
# Starting nonemployment shard 2450000 with 50000 rows
# Finished nonemployment shard 1500000 with 50000 rows in 268.22 seconds
# Finished nonemployment shard 850000 with 50000 rows in 374.062 seconds
# Starting nonemployment shard 2550000 with 50000 rows
# Starting nonemployment shard 2600000 with 50000 rows
# Finished nonemployment shard 1000000 with 50000 rows in 313.103 seconds
# Finished nonemployment shard 1450000 with 50000 rows in 288.606 seconds
# Finished nonemployment shard 1900000 with 50000 rows in 263.081 seconds
# Starting nonemployment shard 2400000 with 50000 rows
# Starting nonemployment shard 2500000 with 50000 rows
# Starting nonemployment shard 2750000 with 50000 rows
# Finished nonemployment shard 2600000 with 50000 rows in 81.7491 seconds
# Finished nonemployment shard 1400000 with 50000 rows in 374.969 seconds
# Finished nonemployment shard 2550000 with 50000 rows in 92.6201 seconds
# Starting nonemployment shard 2650000 with 50000 rows
# Starting nonemployment shard 2800000 with 50000 rows
# Finished nonemployment shard 750000 with 50000 rows in 480.886 seconds
# Starting nonemployment shard 2900000 with 50000 rows
# Finished nonemployment shard 1850000 with 50000 rows in 331.767 seconds
# Finished nonemployment shard 1800000 with 50000 rows in 387.924 seconds
# Starting nonemployment shard 2950000 with 50000 rows
# Finished nonemployment shard 1950000 with 50000 rows in 327.079 seconds
# Finished nonemployment shard 2100000 with 50000 rows in 336.795 seconds
# Finished nonemployment shard 2150000 with 50000 rows in 342.451 seconds
# Starting nonemployment shard 2700000 with 50000 rows
# Starting nonemployment shard 3050000 with 50000 rows
# Finished nonemployment shard 2650000 with 50000 rows in 71.7878 seconds
# Finished nonemployment shard 1700000 with 50000 rows in 379.129 seconds
# Finished nonemployment shard 1650000 with 50000 rows in 446.708 seconds
# Starting nonemployment shard 3000000 with 50000 rows
# Starting nonemployment shard 2850000 with 50000 rows
# Starting nonemployment shard 3250000 with 50000 rows
# Starting nonemployment shard 3350000 with 50000 rows
# Starting nonemployment shard 3150000 with 50000 rows
# Finished nonemployment shard 2450000 with 50000 rows in 217.452 seconds
# Finished nonemployment shard 2000000 with 50000 rows in 471.281 seconds
# Finished nonemployment shard 1300000 with 50000 rows in 497.293 seconds
# Finished nonemployment shard 1750000 with 50000 rows in 479.654 seconds
# Starting nonemployment shard 3200000 with 50000 rows
# Finished nonemployment shard 2200000 with 50000 rows in 255.964 seconds
# Finished nonemployment shard 1250000 with 50000 rows in 505.978 seconds
# Starting nonemployment shard 3450000 with 50000 rows
# Starting nonemployment shard 3650000 with 50000 rows
# Starting nonemployment shard 3550000 with 50000 rows
# Finished nonemployment shard 3050000 with 50000 rows in 104.696 seconds
# Finished nonemployment shard 1150000 with 50000 rows in 534.507 seconds
# Starting nonemployment shard 3100000 with 50000 rows
# Finished nonemployment shard 1200000 with 50000 rows in 647.016 seconds
# Finished nonemployment shard 2850000 with 50000 rows in 94.1477 seconds
# Finished nonemployment shard 950000 with 50000 rows in 632.229 seconds
# Finished nonemployment shard 1050000 with 50000 rows in 654.105 seconds
# Finished nonemployment shard 3450000 with 50000 rows in 69.1568 seconds
# Starting nonemployment shard 3300000 with 50000 rows
# Finished nonemployment shard 2950000 with 50000 rows in 176.275 seconds
# Finished nonemployment shard 3650000 with 50000 rows in 69.544 seconds
# Starting nonemployment shard 3800000 with 50000 rows
# Starting nonemployment shard 3400000 with 50000 rows
# Starting nonemployment shard 3750000 with 50000 rows
# Starting nonemployment shard 3900000 with 50000 rows
# Starting nonemployment shard 3700000 with 50000 rows
# Starting nonemployment shard 4100000 with 50000 rows
# Starting nonemployment shard 3950000 with 50000 rows
# Finished nonemployment shard 3000000 with 50000 rows in 137.022 seconds
# Starting nonemployment shard 4050000 with 50000 rows
# Finished nonemployment shard 1100000 with 50000 rows in 612.437 seconds
# Starting nonemployment shard 3600000 with 50000 rows
# Finished nonemployment shard 2400000 with 50000 rows in 277.432 seconds
# Starting nonemployment shard 3500000 with 50000 rows
# Finished nonemployment shard 2250000 with 50000 rows in 457.181 seconds
# Finished nonemployment shard 3150000 with 50000 rows in 153.7 seconds
# Finished nonemployment shard 3550000 with 50000 rows in 127.436 seconds
# Starting nonemployment shard 4150000 with 50000 rows
# Finished nonemployment shard 3750000 with 50000 rows in 53.9841 seconds
# Finished nonemployment shard 3350000 with 50000 rows in 175.139 seconds
# Finished nonemployment shard 2050000 with 50000 rows in 567.585 seconds
# Finished nonemployment shard 3400000 with 50000 rows in 73.207 seconds
# Finished nonemployment shard 2900000 with 50000 rows in 271.349 seconds
# Finished nonemployment shard 3600000 with 50000 rows in 56.86 seconds
# Finished nonemployment shard 3200000 with 50000 rows in 173.555 seconds
# Finished nonemployment shard 2350000 with 50000 rows in 465.921 seconds
# Starting nonemployment shard 3850000 with 50000 rows
# Starting nonemployment shard 4000000 with 50000 rows
# Finished nonemployment shard 3800000 with 50000 rows in 103.579 seconds
# Starting nonemployment shard 4300000 with 50000 rows
# Finished nonemployment shard 2300000 with 50000 rows in 425.621 seconds
# Finished nonemployment shard 2800000 with 50000 rows in 309.402 seconds
# Finished nonemployment shard 3700000 with 50000 rows in 100.255 seconds
# Finished nonemployment shard 2750000 with 50000 rows in 338.635 seconds
# Starting nonemployment shard 4450000 with 50000 rows
# Starting nonemployment shard 4600000 with 50000 rows
# Finished nonemployment shard 3500000 with 50000 rows in 89.1169 seconds
# Starting nonemployment shard 4200000 with 50000 rows
# Starting nonemployment shard 4350000 with 50000 rows
# Starting nonemployment shard 4250000 with 50000 rows
# Starting nonemployment shard 4500000 with 50000 rows
# Finished nonemployment shard 3250000 with 50000 rows in 254.206 seconds
# Finished nonemployment shard 2700000 with 50000 rows in 310.522 seconds
# Finished nonemployment shard 3300000 with 50000 rows in 155.783 seconds
# Starting nonemployment shard 4850000 with 50000 rows
# Starting nonemployment shard 4800000 with 50000 rows
# Finished nonemployment shard 2500000 with 50000 rows in 399.238 seconds
# Starting nonemployment shard 4400000 with 50000 rows
# Starting nonemployment shard 4950000 with 50000 rows
# Starting nonemployment shard 4650000 with 50000 rows
# Starting nonemployment shard 4700000 with 50000 rows
# Starting nonemployment shard 4750000 with 50000 rows
# Starting nonemployment shard 5000000 with 50000 rows
# Starting nonemployment shard 4550000 with 50000 rows
# Finished nonemployment shard 3100000 with 50000 rows in 239.401 seconds
# Starting nonemployment shard 5100000 with 50000 rows
# Starting nonemployment shard 5200000 with 50000 rows
# Starting nonemployment shard 5300000 with 50000 rows
# Starting nonemployment shard 5250000 with 50000 rows
# Starting nonemployment shard 4900000 with 50000 rows
# Starting nonemployment shard 5050000 with 50000 rows
# Finished nonemployment shard 4100000 with 50000 rows in 220.544 seconds
# Finished nonemployment shard 900000 with 50000 rows in 905.154 seconds
# Starting nonemployment shard 5450000 with 50000 rows
# Finished nonemployment shard 4050000 with 50000 rows in 237.915 seconds
# Starting nonemployment shard 5400000 with 50000 rows
# Finished nonemployment shard 4150000 with 50000 rows in 206.925 seconds
# Finished nonemployment shard 4600000 with 50000 rows in 147.999 seconds
# Starting nonemployment shard 5150000 with 50000 rows
# Finished nonemployment shard 3950000 with 50000 rows in 253.193 seconds
# Starting nonemployment shard 5350000 with 50000 rows
# Starting nonemployment shard 5650000 with 50000 rows
# Finished nonemployment shard 4200000 with 50000 rows in 163.908 seconds
# Starting nonemployment shard 5600000 with 50000 rows
# Finished nonemployment shard 4950000 with 50000 rows in 137.472 seconds
# Finished nonemployment shard 3900000 with 50000 rows in 307.212 seconds
# Finished nonemployment shard 5050000 with 50000 rows in 86.0135 seconds
# Starting nonemployment shard 5500000 with 50000 rows
# Finished nonemployment shard 4250000 with 50000 rows in 199.178 seconds
# Starting nonemployment shard 5550000 with 50000 rows
# Starting nonemployment shard 5750000 with 50000 rows
# Finished nonemployment shard 4000000 with 50000 rows in 232.975 seconds
# Starting nonemployment shard 5850000 with 50000 rows
# Finished nonemployment shard 5100000 with 50000 rows in 168.394 seconds
# Finished nonemployment shard 5300000 with 50000 rows in 166.282 seconds
# Starting nonemployment shard 5950000 with 50000 rows
# Finished nonemployment shard 3850000 with 50000 rows in 271.844 seconds
# Finished nonemployment shard 5000000 with 50000 rows in 192.406 seconds
# Finished nonemployment shard 5200000 with 50000 rows in 188.113 seconds
# Finished nonemployment shard 4450000 with 50000 rows in 261.878 seconds
# Starting nonemployment shard 5700000 with 50000 rows
# Finished nonemployment shard 5250000 with 50000 rows in 190.041 seconds
# Finished nonemployment shard 5400000 with 50000 rows in 128.006 seconds
# Starting nonemployment shard 6050000 with 50000 rows
# Finished nonemployment shard 5150000 with 50000 rows in 120.001 seconds
# Finished nonemployment shard 5750000 with 50000 rows in 71.8818 seconds
# Finished nonemployment shard 5350000 with 50000 rows in 119.844 seconds
# Finished nonemployment shard 4650000 with 50000 rows in 227.028 seconds
# Finished nonemployment shard 5450000 with 50000 rows in 144.885 seconds
# Finished nonemployment shard 5650000 with 50000 rows in 124.277 seconds
# Finished nonemployment shard 5850000 with 50000 rows in 77.0168 seconds
# Starting nonemployment shard 5800000 with 50000 rows
# Finished nonemployment shard 4400000 with 50000 rows in 249.522 seconds
# Finished nonemployment shard 5950000 with 50000 rows in 52.0834 seconds
# Finished nonemployment shard 5550000 with 50000 rows in 95.8604 seconds
# Finished nonemployment shard 4850000 with 50000 rows in 274.406 seconds
# Starting nonemployment shard 5900000 with 50000 rows
# Finished nonemployment shard 4700000 with 50000 rows in 258.525 seconds
# Finished nonemployment shard 4800000 with 50000 rows in 284.598 seconds
# Finished nonemployment shard 4500000 with 50000 rows in 312.786 seconds
# Finished nonemployment shard 5500000 with 50000 rows in 129.432 seconds
# Finished nonemployment shard 4300000 with 50000 rows in 346.125 seconds
# Finished nonemployment shard 4750000 with 50000 rows in 268.27 seconds
# Finished nonemployment shard 5700000 with 50000 rows in 70.5561 seconds
# Finished nonemployment shard 5800000 with 50000 rows in 45.4365 seconds
# Finished nonemployment shard 5900000 with 50000 rows in 43.4248 seconds
# Finished nonemployment shard 4900000 with 50000 rows in 256.775 seconds
# Starting nonemployment shard 6000000 with 50000 rows
# Starting nonemployment shard 6150000 with 50000 rows
# Starting nonemployment shard 6350000 with 50000 rows
# Starting nonemployment shard 6400000 with 50000 rows
# Starting nonemployment shard 6100000 with 50000 rows
# Starting nonemployment shard 6200000 with 50000 rows
# Finished nonemployment shard 6050000 with 50000 rows in 96.9677 seconds
# Starting nonemployment shard 6250000 with 50000 rows
# Finished nonemployment shard 5600000 with 50000 rows in 200.544 seconds
# Finished nonemployment shard 4550000 with 50000 rows in 305.655 seconds
# Starting nonemployment shard 6300000 with 50000 rows
# Starting nonemployment shard 6500000 with 50000 rows
# Starting nonemployment shard 6600000 with 50000 rows
# Starting nonemployment shard 6850000 with 50000 rows
# Finished nonemployment shard 6400000 with 50000 rows in 46.8278 seconds
# Finished nonemployment shard 6350000 with 50000 rows in 54.0685 seconds
# Finished nonemployment shard 4350000 with 50000 rows in 419.707 seconds
# Starting nonemployment shard 6900000 with 50000 rows
# Starting nonemployment shard 6450000 with 50000 rows
# Starting nonemployment shard 6550000 with 50000 rows
# Starting nonemployment shard 6750000 with 50000 rows
# Starting nonemployment shard 6650000 with 50000 rows
# Starting nonemployment shard 6700000 with 50000 rows
# Starting nonemployment shard 7200000 with 50000 rows
# Starting nonemployment shard 7000000 with 50000 rows
# Starting nonemployment shard 7050000 with 50000 rows
# Starting nonemployment shard 7150000 with 50000 rows
# Starting nonemployment shard 6800000 with 50000 rows
# Starting nonemployment shard 7400000 with 50000 rows
# Starting nonemployment shard 7350000 with 50000 rows
# Finished nonemployment shard 7200000 with 50000 rows in 26.5852 seconds

# %%
print '%s has %.1f records (points)' % (dest, os.stat(dest).st_size / float(record_len))
# Out:
# od-JT01-2011.bin has 223234100.0 records (points)

# %% [markdown]
# Randomize point order and write them to binary file for web client
# ------------------------------------------------------------------

# %%
points = []

npoints = os.stat(dest).st_size / record_len

points_file = open(dest, 'rb')
points = [points_file.read(record_len) for i in range(npoints)]
points_file.close()
print "Randomizing %d points..." % len(points)
random.shuffle(points)        

print "Writing data back to binary file %s" % dest
points_file = open(dest, 'wb')
for b in points:
    points_file.write(b)
points_file.close()
print '%s has %.1f records (points)' % (dest, os.stat(dest).st_size / float(record_len))
# Out:
# Randomizing 223234100 points...
# Writing data back to binary file od-JT01-2011.bin
# od-JT01-2011.bin has 223234100.0 records (points)

# %%
import csv, json, os, re, shutil
import subprocess, sys, threading, time, urllib2

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

# %%
try:
    import psycopg2
except:
    # !pip install psycopg2
import psycopg2

# %%
year = 2011
jt = 'JT01'

# %% [markdown]
# Census 2010 subdivisions, for U.S. only:
#
#     ~50 states
#     ~73K census tracts (approx 4000 people)
#     ~218K block groups (approx 1500 people)
#     ~11M blocks
#
# From https://lehd.ces.census.gov/doc/help/onthemap/OnTheMapDataOverview.pdf:
#
# Job dominance is a feature of the LODES data made available because the LEHD data
# infrastructure tracks jobs as its primary unit instead of people. As such, the system naturally
# captures more than one job per person when available in the data. The dominant (or primary)
# job for an individual is defined as the job that earned the individual the most money.
# Constructed this way, the number of primary jobs should be equal to the number of workers.
# LODES and OnTheMap release “Primary” jobs and “All” jobs so that “Non-primary” jobs can be
# can be calculated through subtraction.
#
# <img src="lodes-table-description.png">

# %% [markdown]
# Download all state LODES data
# -----------------------------

# %%
def download_lodes7(state):
    curdir = "capture/lodes7/%s/" % state
    for part in ['main', 'aux']:
        # http://lehd.ces.census.gov/data/lodes/LODES7/LODESTechDoc7.0.pdf
        url = ('http://lehd.ces.census.gov/data/lodes/LODES7/{state}/od/{state}_od_{part}_{jt}_{year}.csv.gz'
                   .format(state=state, part=part, year=year, jt=jt))
        filename = curdir + os.path.basename(url)
        download_file(url, filename)
        gunzip_file(filename)

threads = []


for name in state_names:
    threads.append(threading.Thread(target=download_lodes7, args=(name,)))
    threads[-1].start()
    
for t in threads:
    t.join()
# Out:
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ak/od/ak_od_main_JT01_2011.csv.gz to capture/lodes7/ak/ak_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/al/od/al_od_main_JT01_2011.csv.gz to capture/lodes7/al/al_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ar/od/ar_od_main_JT01_2011.csv.gz to capture/lodes7/ar/ar_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ca/od/ca_od_main_JT01_2011.csv.gz to capture/lodes7/ca/ca_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/az/od/az_od_main_JT01_2011.csv.gz to capture/lodes7/az/az_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/co/od/co_od_main_JT01_2011.csv.gz to capture/lodes7/co/co_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ct/od/ct_od_main_JT01_2011.csv.gz to capture/lodes7/ct/ct_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/dc/od/dc_od_main_JT01_2011.csv.gz to capture/lodes7/dc/dc_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/de/od/de_od_main_JT01_2011.csv.gz to capture/lodes7/de/de_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/fl/od/fl_od_main_JT01_2011.csv.gz to capture/lodes7/fl/fl_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ga/od/ga_od_main_JT01_2011.csv.gz to capture/lodes7/ga/ga_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/hi/od/hi_od_main_JT01_2011.csv.gz to capture/lodes7/hi/hi_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ia/od/ia_od_main_JT01_2011.csv.gz to capture/lodes7/ia/ia_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/id/od/id_od_main_JT01_2011.csv.gz to capture/lodes7/id/id_od_main_JT01_2011.csv.gz
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7
od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ut/ut_od_aux_JT01_2011.csv.gz
# Done, wrote 4778078 bytes to capture/lodes7/ms/ms_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ms/ms_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/ut/ut_od_aux_JT01_2011.csv
# Done, wrote 476245 bytes to capture/lodes7/de/de_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/de/de_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/de/de_od_aux_JT01_2011.csv
# Success, created capture/lodes7/ms/ms_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ms/od/ms_od_aux_JT01_2011.csv.gz to capture/lodes7/ms/ms_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/or/or_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/or/od/or_od_aux_JT01_2011.csv.gz to capture/lodes7/or/or_od_aux_JT01_2011.csv.gz
# Done, wrote 71344 bytes to capture/lodes7/mt/mt_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/mt/mt_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/mt/mt_od_aux_JT01_2011.csv
# Done, wrote 526717 bytes to capture/lodes7/wv/wv_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/wv/wv_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/wv/wv_od_aux_JT01_2011.csv
# Done, wrote 2808233 bytes to capture/lodes7/id/id_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/id/id_od_main_JT01_2011.csv.gz
# Done, wrote 1533474 bytes to capture/lodes7/nd/nd_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/nd/nd_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/nd/nd_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/nd/od/nd_od_aux_JT01_2011.csv.gz to capture/lodes7/nd/nd_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/id/id_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/id/od/id_od_aux_JT01_2011.csv.gz to capture/lodes7/id/id_od_aux_JT01_2011.csv.gz
# Done, wrote 439292 bytes to capture/lodes7/ms/ms_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ms/ms_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ms/ms_od_aux_JT01_2011.csv
# Done, wrote 5257754 bytes to capture/lodes7/ar/ar_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ar/ar_od_main_JT01_2011.csv.gz
# Done, wrote 2637451 bytes to capture/lodes7/me/me_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/me/me_od_main_JT01_2011.csv.gz
# Done, wrote 255206 bytes to capture/lodes7/nd/nd_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/nd/nd_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/nd/nd_od_aux_JT01_2011.csv
# Done, wrote 2199931 bytes to capture/lodes7/dc/dc_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/dc/dc_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/me/me_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/me/od/me_od_aux_JT01_2011.csv.gz to capture/lodes7/me/me_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ar/ar_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ar/od/ar_od_aux_JT01_2011.csv.gz to capture/lodes7/ar/ar_od_aux_JT01_2011.csv.gz
# Done, wrote 196993 bytes to capture/lodes7/id/id_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/id/id_od_aux_JT01_2011.csv.gz
# Done, wrote 662752 bytes to capture/lodes7/or/or_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/or/or_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/id/id_od_aux_JT01_2011.csv
# Success, created capture/lodes7/dc/dc_od_aux_JT01_2011.csv
# Success, created capture/lodes7/or/or_od_aux_JT01_2011.csv
# Done, wrote 1666271 bytes to capture/lodes7/sd/sd_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/sd/sd_od_main_JT01_2011.csv.gz
# Done, wrote 8297567 bytes to capture/lodes7/sc/sc_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/sc/sc_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/sd/sd_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/sd/od/sd_od_aux_JT01_2011.csv.gz to capture/lodes7/sd/sd_od_aux_JT01_2011.csv.gz
# Done, wrote 99530 bytes to capture/lodes7/me/me_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/me/me_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/me/me_od_aux_JT01_2011.csv
# Done, wrote 2490557 bytes to capture/lodes7/nh/nh_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/nh/nh_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/nh/nh_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/nh/od/nh_od_aux_JT01_2011.csv.gz to capture/lodes7/nh/nh_od_aux_JT01_2011.csv.gz
# Done, wrote 458244 bytes to capture/lodes7/ar/ar_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ar/ar_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ar/ar_od_aux_JT01_2011.csv
# Done, wrote 150275 bytes to capture/lodes7/sd/sd_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/sd/sd_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/sd/sd_od_aux_JT01_2011.csv
# Success, created capture/lodes7/sc/sc_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/sc/od/sc_od_aux_JT01_2011.csv.gz to capture/lodes7/sc/sc_od_aux_JT01_2011.csv.gz
# Done, wrote 488858 bytes to capture/lodes7/nh/nh_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/nh/nh_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/nh/nh_od_aux_JT01_2011.csv
# Done, wrote 582434 bytes to capture/lodes7/sc/sc_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/sc/sc_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/sc/sc_od_aux_JT01_2011.csv
# Done, wrote 7417507 bytes to capture/lodes7/ky/ky_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ky/ky_od_main_JT01_2011.csv.gz
# Done, wrote 4077321 bytes to capture/lodes7/ne/ne_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ne/ne_od_main_JT01_2011.csv.gz
# Done, wrote 5622799 bytes to capture/lodes7/ks/ks_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ks/ks_od_main_JT01_2011.csv.gz
# Done, wrote 8736100 bytes to capture/lodes7/la/la_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/la/la_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/ne/ne_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ne/od/ne_od_aux_JT01_2011.csv.gz to capture/lodes7/ne/ne_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ky/ky_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ky/od/ky_od_aux_JT01_2011.csv.gz to capture/lodes7/ky/ky_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ks/ks_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ks/od/ks_od_aux_JT01_2011.csv.gz to capture/lodes7/ks/ks_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/la/la_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/la/od/la_od_aux_JT01_2011.csv.gz to capture/lodes7/la/la_od_aux_JT01_2011.csv.gz
# Done, wrote 399960 bytes to capture/lodes7/ne/ne_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ne/ne_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ne/ne_od_aux_JT01_2011.csv
# Done, wrote 4378081 bytes to capture/lodes7/nv/nv_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/nv/nv_od_main_JT01_2011.csv.gz
# Done, wrote 484904 bytes to capture/lodes7/la/la_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/la/la_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/la/la_od_aux_JT01_2011.csv
# Done, wrote 956033 bytes to capture/lodes7/ky/ky_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ky/ky_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/nv/nv_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/nv/od/nv_od_aux_JT01_2011.csv.gz to capture/lodes7/nv/nv_od_aux_JT01_2011.csv.gz
# Done, wrote 804875 bytes to capture/lodes7/ks/ks_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ks/ks_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ky/ky_od_aux_JT01_2011.csv
# Success, created capture/lodes7/ks/ks_od_aux_JT01_2011.csv
# Done, wrote 11804765 bytes to capture/lodes7/mn/mn_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/mn/mn_od_main_JT01_2011.csv.gz
# Done, wrote 6872364 bytes to capture/lodes7/ct/ct_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ct/ct_od_main_JT01_2011.csv.gz
# Done, wrote 11618613 bytes to capture/lodes7/tn/tn_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/tn/tn_od_main_JT01_2011.csv.gz
# Done, wrote 321746 bytes to capture/lodes7/nv/nv_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/nv/nv_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/nv/nv_od_aux_JT01_2011.csv
# Success, created capture/lodes7/ct/ct_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ct/od/ct_od_aux_JT01_2011.csv.gz to capture/lodes7/ct/ct_od_aux_JT01_2011.csv.gz
# Done, wrote 12119828 bytes to capture/lodes7/mo/mo_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/mo/mo_od_main_JT01_2011.csv.gz
# Done, wrote 6648307 bytes to capture/lodes7/ia/ia_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ia/ia_od_main_JT01_2011.csv.gz
# Done, wrote 8888397 bytes to capture/lodes7/al/al_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/al/al_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/mn/mn_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/mn/od/mn_od_aux_JT01_2011.csv.gz to capture/lodes7/mn/mn_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/tn/tn_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/tn/od/tn_od_aux_JT01_2011.csv.gz to capture/lodes7/tn/tn_od_aux_JT01_2011.csv.gz
# Done, wrote 7481275 bytes to capture/lodes7/ok/ok_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ok/ok_od_main_JT01_2011.csv.gz
# Done, wrote 11249202 bytes to capture/lodes7/wi/wi_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/wi/wi_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/ia/ia_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ia/od/ia_od_aux_JT01_2011.csv.gz to capture/lodes7/ia/ia_od_aux_JT01_2011.csv.gz
# Done, wrote 817164 bytes to capture/lodes7/ct/ct_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/
od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ny/ny_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/fl/fl_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/fl/od/fl_od_aux_JT01_2011.csv.gz to capture/lodes7/fl/fl_od_aux_JT01_2011.csv.gz
# Done, wrote 591271 bytes to capture/lodes7/fl/fl_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/fl/fl_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/fl/fl_od_aux_JT01_2011.csv
# Success, created capture/lodes7/ny/ny_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ny/od/ny_od_aux_JT01_2011.csv.gz to capture/lodes7/ny/ny_od_aux_JT01_2011.csv.gz
# Done, wrote 3862738 bytes to capture/lodes7/ny/ny_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ny/ny_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ny/ny_od_aux_JT01_2011.csv
# Done, wrote 52515789 bytes to capture/lodes7/tx/tx_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/tx/tx_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/tx/tx_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/tx/od/tx_od_aux_JT01_2011.csv.gz to capture/lodes7/tx/tx_od_aux_JT01_2011.csv.gz
# Done, wrote 1092093 bytes to capture/lodes7/tx/tx_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/tx/tx_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/tx/tx_od_aux_JT01_2011.csv
# Done, wrote 73712225 bytes to capture/lodes7/ca/ca_od_main_JT01_2011.csv.gz
# gunzipping capture/lodes7/ca/ca_od_main_JT01_2011.csv.gz
# Success, created capture/lodes7/ca/ca_od_main_JT01_2011.csv
# Downloading http://lehd.ces.census.gov/data/lodes/LODES7/ca/od/ca_od_aux_JT01_2011.csv.gz to capture/lodes7/ca/ca_od_aux_JT01_2011.csv.gz
# Done, wrote 842114 bytes to capture/lodes7/ca/ca_od_aux_JT01_2011.csv.gz
# gunzipping capture/lodes7/ca/ca_od_aux_JT01_2011.csv.gz
# Success, created capture/lodes7/ca/ca_od_aux_JT01_2011.csv

# %% [markdown]
# <h1>Import LODES Origin-Destination (OD) CSV files into psql</h1>

# %%
def drop_and_create_od_table():
    cmd = (
        "DROP TABLE IF EXISTS od_{jt}_{year};\n"
        "CREATE TABLE od_{jt}_{year} ( "
        "gid serial NOT NULL, "
        "w_geocode character varying(15), "
        "h_geocode character varying(15), "
        "S000 integer, "
        "SA01 integer, " 
        "SA02 integer, "
        "SA03 integer, "
        "SE01 integer, "
        "SE02 integer, "
        "SE03 integer, "
        "SI01 integer, "
        "SI02 integer, "
        "SI03 integer, "
        "createdate character varying(8));\n"
        "CREATE UNIQUE INDEX ON od_{jt}_{year} (gid);\n" 
        "CREATE INDEX ON od_{jt}_{year} (w_geocode);\n"
        "CREATE INDEX ON od_{jt}_{year} (h_geocode);\n"
        "CREATE INDEX ON od_{jt}_{year} (s000);\n"
    ).format(jt=jt, year=year)
    psql(cmd)

drop_and_create_od_table()

def import_csv_to_psql(filename):
    cmd = (
        "COPY od_{jt}_{year}("
        "w_geocode,h_geocode,S000,SA01,"
        "SA02,SA03,SE01,SE02,SE03,SI01,"
        "SI02,SI03,createdate) FROM "
        "'{filename}' "
        "DELIMITER ',' CSV HEADER;\n"
         ).format(jt=jt, year=year, filename=os.path.abspath(filename))
    psql(cmd)

threads = []

def import_lodes7_state(state):
    sys.stdout.write('Importing state %s\n' % state)
    for part in ['main', 'aux']:
        f = 'capture/lodes7/{state}/{state}_od_{part}_{jt}_{year}.csv'.format(jt=jt, state=state, part=part, year=year)
        import_csv_to_psql(f)
for state in state_names:
    threads.append(threading.Thread(target=import_lodes7_state, args=(state,)))
    threads[-1].start()

for t in threads:
    t.join()
# Out:
# DROP TABLE IF EXISTS od_JT01_2011;
# CREATE TABLE od_JT01_2011 ( gid serial NOT NULL, w_geocode character varying(15), h_geocode character varying(15), S000 integer, SA01 integer, SA02 integer, SA03 integer, SE01 integer, SE02 integer, SE03 integer, SI01 integer, SI02 integer, SI03 integer, createdate character varying(8));
# CREATE UNIQUE INDEX ON od_JT01_2011 (gid);
# CREATE INDEX ON od_JT01_2011 (w_geocode);
# CREATE INDEX ON od_JT01_2011 (h_geocode);
# CREATE INDEX ON od_JT01_2011 (s000);
# Finished execution: DROP TABLE
# CREATE TABLE
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# CREATE INDEX
# Importing state ak
# Importing state al
# Importing state ar
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ak/ak_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state az
# Importing state ca
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/al/al_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ar/ar_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state co
# Importing state ct
# Importing state dc
# Importing state de
# Importing state fl
# Importing state ga
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/co/co_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state hi
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ca/ca_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state ia
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/fl/fl_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/de/de_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state id
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/dc/dc_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state il
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/hi/hi_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state in
# Importing state ks
# Importing state ky
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ia/ia_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ga/ga_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state la
# Importing state ma
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/id/id_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ks/ks_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/il/il_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state md
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/in/in_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state me
# Importing state mi
# Importing state mn
# Importing state mo
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/la/la_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mi/mi_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state ms
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ma/ma_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/md/md_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/me/me_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state mt
# Importing state nc
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mo/mo_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state nd
# Importing state ne
# Importing state nh
# Importing state nm
# Importing state nj
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ms/ms_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state nv
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ne/ne_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state ny
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nc/nc_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state oh
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nd/nd_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state ok
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nh/nh_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state or
# Importing state pa
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ny/ny_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state ri
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/oh/oh_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state sc
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ok/ok_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state sd
# Importing state tn
# Importing state tx
# Importing state ut
# Importing state va
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ri/ri_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state vt
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/sc/sc_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state wa
# Importing state wi
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/sd/sd_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state wv
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/va/va_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Importing state wy
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ut/ut_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/tx/tx_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wi/wi_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wy/wy_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 129577
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/dc/dc_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 202712
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ak/ak_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 13315
# Finished execution: COPY 262068
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mt/mt_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nd/nd_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 286864
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/sd/sd_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 37578
# Finished execution: COPY 19276
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nj/nj_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 382955
# Finished execution: COPY 426769
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nh/nh_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 70545
# Finished execution: COPY 814549
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ms/ms_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 883631
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ar/ar_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 57729
# Finished execution: COPY 59481
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ky/ky_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 953121
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ks/ks_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 953761
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ut/ut_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 22305
# Finished execution: COPY 118305
# Finished execution: COPY 1472935
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/al/al_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 59893
# Finished execution: COPY 1774102
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/md/md_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wv/wv_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 1825572
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ct/ct_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 345469
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/co/co_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/hi/hi_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 4521
# Finished execution: COPY 23604
# Finished execution: COPY 253832
# Finished execution: COPY 1249735
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ky/ky_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 2181570
# Finished execution: COPY 1463114
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/in/in_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/la/la_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 61139
# Finished execution: COPY 137320
# Finished execution: COPY 513321
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wa/wa_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wv/wv_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 141475
# Finished execution: COPY 75638
# Finished execution: COPY 2531640
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/va/va_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 2461859
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ma/ma_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 264647
# Finished execution: COPY 208734
# Finished execution: COPY 2997346
# Finished execution: COPY 488437
# Finished execution: COPY 1123684
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ga/ga_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/id/id_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ia/ia_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 697087
# Finished execution: COPY 3000540
# Finished execution: COPY 335945
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ne/ne_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nc/nc_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mt/mt_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 1188555
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ct/ct_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 24730
# Finished execution: COPY 3127825
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mn/mn_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 450550
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mi/mi_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/me/me_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 112408
# Finished execution: COPY 54717
# Finished execution: COPY 84353
# Finished execution: COPY 121652
# Finished execution: COPY 7492
# Finished execution: COPY 137091
# Finished execution: COPY 49902
# Finished execution: COPY 11788
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nm/nm_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 2832806
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nj/nj_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 337563
# Finished execution: COPY 599926
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nm/nm_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 28710
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/or/or_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 1232751
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ok/ok_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 35683
# Finished execution: COPY 195258
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wy/wy_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 17597
# Finished execution: COPY 4519207
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/il/il_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 2045031
# Finished execution: COPY 2027668
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mo/mo_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/mn/mn_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 217807
# Finished execution: COPY 1296953
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/pa/pa_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/or/or_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 82797
# Finished execution: COPY 95712
# Finished execution: COPY 195059
# Finished execution: COPY 248881
# Finished execution: COPY 5877024
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/de/de_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/fl/fl_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 71070
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nv/nv_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 4014802
# Finished execution: COPY 6218457
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/oh/oh_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 65206
# Finished execution: COPY 161370
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ny/ny_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 788666
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/nv/nv_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 40659
# Finished execution: COPY 560825
# Finished execution: COPY 8605201
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/tn/tn_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/tx/tx_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 126459
# Finished execution: COPY 4475595
# Finished execution: COPY 325161
# Finished execution: COPY 1394448
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/pa/pa_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/sc/sc_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ri/ri_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 273663
# Finished execution: COPY 75746
# Finished execution: COPY 55243
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/vt/vt_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 1968011
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/tn/tn_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 1907574
# Finished execution: COPY 201872
# Finished execution: COPY 2200595
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wi/wi_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/vt/vt_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/wa/wa_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 23306
# Finished execution: COPY 151853
# Finished execution: COPY 64904
# Finished execution: COPY 70907
# Finished execution: COPY 12042688
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/az/az_od_main_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/ca/ca_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 91452
# Finished execution: COPY 1953970
# COPY od_JT01_2011(w_geocode,h_geocode,S000,SA01,SA02,SA03,SE01,SE02,SE03,SI01,SI02,SI03,createdate) FROM '/mnt/ssd/rsargent/projects/unemployed-dotmap/unemployed-dotmap/data-visualization-tools/examples/lodes/capture/lodes7/az/az_od_aux_JT01_2011.csv' DELIMITER ',' CSV HEADER;
# Finished execution: COPY 30465

# %% [markdown]
# Table structure
# ---------------
#
#     For od_{JT00|JT01}_{year}

# %%
psql('\d od_{jt}_{year}'.format(jt=jt, year=year))
# Out:
# \d od_jt00_2011
# Finished execution: Table "public.od_jt00_2011"
#    Column   |         Type          |                         Modifiers
# ------------+-----------------------+------------------------------------------------------------
#  gid        | integer               | not null default nextval('od_jt00_2011_gid_seq'::regclass)
#  w_geocode  | character varying(15) |
#  h_geocode  | character varying(15) |
#  s000       | integer               |
#  sa01       | integer               |
#  sa02       | integer               |
#  sa03       | integer               |
#  se01       | integer               |
#  se02       | integer               |
#  se03       | integer               |
#  si01       | integer               |
#  si02       | integer               |
#  si03       | integer               |
#  createdate | character varying(8)  |
#  distance   | double precision      |
# Indexes:
#     "od_jt00_2011_gid_idx" UNIQUE, btree (gid)
#     "od_jt00_2011_h_geocode_idx" btree (h_geocode)
#     "od_jt00_2011_s000_idx" btree (s000)
#     "od_jt00_2011_w_geocode_idx" btree (w_geocode)

# %%
psql('SELECT COUNT(*) FROM tl_2010_tabblock10')

# %%
# Wide display
from IPython.core.display import display, HTML
display(HTML("<style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>"))
# Out:
# <style>#notebook-container { margin-left:-14px; width:calc(100% + 27px) !important; }</style>

# %%
import csv, json, os, math, numbers, pandas, re, scipy, scipy.sparse, shutil
import subprocess, sys, threading, time, urllib2

def exec_ipynb(filename_or_url):
    nb = (urllib2.urlopen(filename_or_url) if re.match(r'https?:', filename_or_url) else open(filename_or_url)).read()
    jsonNb = json.loads(nb)
    #check for the modified formatting of Jupyter Notebook v4
    if(jsonNb['nbformat'] == 4):
        exec '\n'.join([''.join(cell['source']) for cell in jsonNb['cells'] if cell['cell_type'] == 'code']) in globals()
    else:
        exec '\n'.join([''.join(cell['input']) for cell in jsonNb['worksheets'][0]['cells'] if cell['cell_type'] == 'code']) in globals()

exec_ipynb('timelapse-utilities.ipynb')

# %%
pandas.options.display.max_colwidth = 300

# %% [markdown]
# ## Download File Templates for 5-year data
#
# 5-year data is a 5-year average, ending in the named year.
# So the recently released ACS2016-5year actually is from 2012-2016

# %%
#src = 'https://www2.census.gov/programs-surveys/acs/summary_file/2015/data/2015_1yr_Summary_FileTemplates.zip'
#dest = 'capture/ACS2015_1year/2015_1yr_Summary_FileTemplates.zip'
#download_file(src, dest)
#templates = unzip_file(dest)

def download_file_templates(year):
    src = 'https://www2.census.gov/programs-surveys/acs/summary_file/{year}/data/{year}_5yr_Summary_FileTemplates.zip'.format(**locals())

    # Special-case 2010
    src = src.replace('2010_5yr_Summary_File', '2010_5yr_SummaryFile')
    
    dest = 'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates.zip'.format(**locals())
    download_file(src, dest)
    templates = unzip_file(dest)
    
for year in range(2009, 2017):
    download_file_templates(year)
# Out:
# capture/ACS2009_5year/2009_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2009_5year/2009_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2010_5year/2010_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2010_5year/2010_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2011_5year/2011_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2011_5year/2011_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2012_5year/2012_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2012_5year/2012_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2013_5year/2013_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2013_5year/2013_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2014_5year/2014_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2014_5year/2014_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2015_5year/2015_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2015_5year/2015_5yr_Summary_FileTemplates.zip already unzipped
# capture/ACS2016_5year/2016_5yr_Summary_FileTemplates.zip already downloaded
# capture/ACS2016_5year/2016_5yr_Summary_FileTemplates.zip already unzipped

# %%
# !ls -l capture/ACS2015_1year/2015_1yr_Summary_FileTemplates/Templates | head

# %% [markdown]
# ## Download ACS2015 5-year data (tract and block group)

# %%
process_year=2009

# %%
def download_data(year):
    filename = 'Tracts_Block_Groups_Only'
    if year < 2011:
        filename += '.zip'
    else:
        filename += '.tar.gz'
    src = 'https://www2.census.gov/programs-surveys/acs/summary_file/{year}/data/5_year_entire_sf/{filename}'.format(**locals())
    dest = 'capture/ACS{year}_5year/{filename}'.format(**locals())

    if os.path.exists(dest):
        print '{dest} already exists, skipping'.format(**locals())
    else:
        try:
            os.unlink(filename)
        except OSError:
            pass
        cmd = '/usr/bin/curl'
        cmd += " -H 'User-Agent:Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'"
        cmd += ' {src}'.format(**locals())
        cmd += ' >{dest}'.format(**locals())
        try:
            os.makedirs(os.path.dirname(dest))
        except OSError:
            pass
        print cmd
        subprocess_check(cmd)
        print 'Downloaded to {dest}'.format(**locals())

for year in range(2009, 2017):
    download_data(year)
# Out:
# capture/ACS2009_5year/Tracts_Block_Groups_Only.zip already exists, skipping
# capture/ACS2010_5year/Tracts_Block_Groups_Only.zip already exists, skipping
# capture/ACS2011_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2012_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2013_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2014_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2015_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping
# capture/ACS2016_5year/Tracts_Block_Groups_Only.tar.gz already exists, skipping

# %%
# !ls -l capture/ACS*/Tracts*
# Out:
# -rw-rw-r-- 1 rsargent rsargent 2806502508 Oct  5 07:52 capture/ACS2009_5year/Tracts_Block_Groups_Only.zip
# -rw-rw-r-- 1 rsargent rsargent 3369803296 Oct  5 07:59 capture/ACS2010_5year/Tracts_Block_Groups_Only.zip
# -rw-rw-r-- 1 rsargent rsargent 3297054880 Oct  5 08:12 capture/ACS2011_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3651813394 Oct  5 07:33 capture/ACS2012_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3769295680 Oct  5 07:45 capture/ACS2013_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3757945352 Oct  5 07:59 capture/ACS2014_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3747109902 Dec  2  2016 capture/ACS2015_5year/Tracts_Block_Groups_Only.tar.gz
# -rw-rw-r-- 1 rsargent rsargent 3780352044 Feb 14 15:00 capture/ACS2016_5year/Tracts_Block_Groups_Only.tar.gz

# %%
# !mkdir -p capture/ACS2005_5year
# !mv  capture/ACS2005_5year
#
# !cd capture/ACS2005_5year; tar xvfz Tracts_Block_Groups_Only.tar.gz >/dev/null
#
# !wget --header="User-Agent: Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.97 Safari/537.11" https://www2.census.gov/programs-surveys/acs/summary_file/2015/data/5_year_entire_sf/2015_ACS_Geography_Files.zip
#
# !mv 2015_ACS_Geography_Files.zip capture/ACS2005_5year
# 
# unzip_file('capture/ACS2005_5year/2015_ACS_Geography_Files.zip')

# %%
def download_geography_data(year, force_regenerate=False):
    fname = ("{year}_ACS_Geography_Files.zip").format(**locals())
    cdir = ("capture/ACS{year}_5year").format(**locals())
    fpath = ("{cdir}/{fname}").format(**locals())
    
    if os.path.exists(fpath) and not force_regenerate:
        print '{fpath} already exists, skipping'.format(**locals())
        return
    
    url_template = "https://www2.census.gov/programs-surveys/acs/summary_file/{year}/data/5_year_entire_sf/{fname}"
    url = url_template.format(**locals())
    # !wget --header="User-Agent: Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.97 Safari/537.11" $url
    
    # !mv $fname $cdir
    unzip_file(fpath)
    print "Downloaded %s to %s" % (fname,fpath)

# %%
download_geography_data(process_year)
# Out:
# --2018-02-28 22:16:08--  https://www2.census.gov/programs-surveys/acs/summary_file/2009/data/5_year_entire_sf/2009_ACS_Geography_Files.zip
# Resolving www2.census.gov (www2.census.gov)... 23.36.91.141, 2600:1408:7:291::208c, 2600:1408:7:2a5::208c
# Connecting to www2.census.gov (www2.census.gov)|23.36.91.141|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2018-02-28 22:16:09 ERROR 404: Not Found.
#
# mv: cannot stat '2009_ACS_Geography_Files.zip': No such file or directory
# Unzipping capture/ACS2009_5year/2009_ACS_Geography_Files.zip into capture/ACS2009_5year/2009_ACS_Geography_Files.tmp
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-92b0ec7c920e> in <module>()
# ----> 1 download_geography_data(process_year)
#
# <ipython-input-5-501fcfb5e3f8> in download_geography_data(year, force_regenerate)
#      13
#      14     get_ipython().system(u'mv $fname $cdir')
# ---> 15     unzip_file(fpath)
#      16     print "Downloaded %s to %s" % (fname,fpath)
#
# <string> in unzip_file(filename)
#
# <string> in subprocess_check(*args, **kwargs)
#
# Exception: Call to subprocess_check failed with return code 9
# Standard error:
# unzip:  cannot find or open capture/ACS2009_5year/2009_ACS_Geography_Files.zip, capture/ACS2009_5year/2009_ACS_Geography_Files.zip.zip or capture/ACS2009_5year/2009_ACS_Geography_Files.zip.ZIP.
# Standard out:

# %% [markdown]
# ## Read CSV utility functions

# %%
def read_acs_5year_template(year, seqno):
    for template in ['capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates/Seq{seqno}.xls',
                     'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates/{year}_5yr_Templates/Seq{seqno}.xls',
                     'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates/seq/Seq{seqno}.xls',
                     'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates/templates/Seq{seqno}.xls',
                     'capture/ACS{year}_5year/{year}_5yr_Summary_FileTemplates/Seq%04d.xls'%(seqno)]:
        path = template.format(**locals())
        #print 'Checking for {path}'.format(**locals())
        if os.path.exists(path):
            return pandas.read_excel(path)
    #print 'yo could not find {year}:{seqno}'.format(**locals())
    return None

def find_acs_5year_data(year, state, seqno):
    fname = 'e%d5%s%04d000.txt' % (year, state, seqno)
    for template in ['capture/ACS{year}_5year/group2/{fname}',
                     'capture/ACS{year}_5year/data/tab4/sumfile/prod/2012thru2016/group2/{fname}',
                     'capture/ACS{year}_5year/tab4/sumfile/prod/2010thru2014/group2/{fname}',
                     'capture/ACS{year}_5year/tab4/sumfile/prod/2008thru2012/group2/{fname}',
                     'capture/ACS{year}_5year/tab4/sumfile/prod/2006thru2010/group2/{fname}']:
        path = template.format(**locals())
        #print 'Checking for {path}'.format(**locals())
        if os.path.exists(path):
            return path
    print 'Could not find {year}:{seqno} file {fname}'.format(**locals())
    return None

# Combine template header and data into pandas frame
def read_acs_5year_data(year, state, seqno):
    header = read_acs_5year_template(year, seqno)
    data_fname = find_acs_5year_data(year, state, seqno)
    if not data_fname:
        return None
    else:
        data = pandas.read_csv(data_fname,
                               index_col=False,
                               dtype={'FILEID':numpy.str,
                                      'FILETYPE':numpy.str,
                                      'STUSAB':numpy.str,
                                      'CHARITER':numpy.str,
                                      'SEQUENCE':numpy.str,
                                      'LOGRECNO':numpy.str},
                               header=None,
                               names=header.columns.values)
        return data

# %%
read_acs_5year_template(process_year, 1)
# Out:
#    FILEID  FILETYPE  STUSAB  CHARITER  SEQUENCE  LOGRECNO  \
# 0  FILEID  FILETYPE  STUSAB  CHARITER  SEQUENCE  LOGRECNO
#
#                                                                                                                                                                            B07401_001  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 1 year and over in the United States% Total living in area 1 year ago:
#
#                                                                                                                                                         B07401_002  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 1 year and over in the United States%  1 to 4 years
#
#                                                                                                                                                          B07401_003  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 1 year and over in the United States%  5 to 17 years
#
#                                                                                                                                                            B07401_004  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 1 year and over in the United States%  18 and 19 years
#
#                                                                                                                  ...                                                                                                                  \
# 0                                                                                                                ...
#
#                                                                                                                                                                                                                                                          B07409_021  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different county within same state:% High school graduate (includes equivalency)
#
#                                                                                                                                                                                                                                                 B07409_022  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different county within same state:% Some college or associate's degree
#
#                                                                                                                                                                                                                                B07409_023  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different county within same state:% Bachelor's degree
#
#                                                                                                                                                                                                                                              B07409_024  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different county within same state:% Graduate or professional degree
#
#                                                                                                                                                                                          B07409_025  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:
#
#                                                                                                                                                                                                                          B07409_026  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:% Less than high school graduate
#
#                                                                                                                                                                                                                                       B07409_027  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:% High school graduate (includes equivalency)
#
#                                                                                                                                                                                                                              B07409_028  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:% Some college or associate's degree
#
#                                                                                                                                                                                                             B07409_029  \
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:% Bachelor's degree
#
#                                                                                                                                                                                                                           B07409_030
# 0  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES for  Population 25 years and over in the United States% Moved to different state:% Graduate or professional degree
#
# [1 rows x 236 columns]

# %%
read_acs_5year_data(process_year,'pa', 1)
# Out:
# Checking for capture/ACS2010_5year/group2/e20105pa0001000.txt
# Checking for capture/ACS2010_5year/data/tab4/sumfile/prod/2012thru2016/group2/e20105pa0001000.txt
# Checking for capture/ACS2010_5year/tab4/sumfile/prod/2010thru2014/group2/e20105pa0001000.txt
# Checking for capture/ACS2010_5year/tab4/sumfile/prod/2008thru2012/group2/e20105pa0001000.txt
# Checking for capture/ACS2010_5year/tab4/sumfile/prod/2006thru2010/group2/e20105pa0001000.txt
#       FILEID FILETYPE STUSAB CHARITER SEQUENCE LOGRECNO  B07401_001  \
# 0      ACSSF   2010e5     pa      000     0001  0011708         NaN
# 1      ACSSF   2010e5     pa      000     0001  0011709         NaN
# 2      ACSSF   2010e5     pa      000     0001  0011710         NaN
# 3      ACSSF   2010e5     pa      000     0001  0011711         NaN
# 4      ACSSF   2010e5     pa      000     0001  0011712         NaN
# 5      ACSSF   2010e5     pa      000     0001  0011713         NaN
# 6      ACSSF   2010e5     pa      000     0001  0011714         NaN
# 7      ACSSF   2010e5     pa      000     0001  0011715         NaN
# 8      ACSSF   2010e5     pa      000     0001  0011716         NaN
# 9      ACSSF   2010e5     pa      000     0001  0011717         NaN
# 10     ACSSF   2010e5     pa      000     0001  0011718         NaN
# 11     ACSSF   2010e5     pa      000     0001  0011719         NaN
# 12     ACSSF   2010e5     pa      000     0001  0011720         NaN
# 13     ACSSF   2010e5     pa      000     0001  0011721         NaN
# 14     ACSSF   2010e5     pa      000     0001  0011722         NaN
# 15     ACSSF   2010e5     pa      000     0001  0011723         NaN
# 16     ACSSF   2010e5     pa      000     0001  0011724         NaN
# 17     ACSSF   2010e5     pa      000     0001  0011725         NaN
# 18     ACSSF   2010e5     pa      000     0001  0011726         NaN
# 19     ACSSF   2010e5     pa      000     0001  0011727         NaN
# 20     ACSSF   2010e5     pa      000     0001  0011728         NaN
# 21     ACSSF   2010e5     pa      000     0001  0011729         NaN
# 22     ACSSF   2010e5     pa      000     0001  0011730         NaN
# 23     ACSSF   2010e5     pa      000     0001  0011731         NaN
# 24     ACSSF   2010e5     pa      000     0001  0011732         NaN
# 25     ACSSF   2010e5     pa      000     0001  0011733         NaN
# 26     ACSSF   2010e5     pa      000     0001  0011734         NaN
# 27     ACSSF   2010e5     pa      000     0001  0011735         NaN
# 28     ACSSF   2010e5     pa      000     0001  0011736         NaN
# 29     ACSSF   2010e5     pa      000     0001  0011737         NaN
# ...      ...      ...    ...      ...      ...      ...         ...
# 12928  ACSSF   2010e5     pa      000     0001  0024636         NaN
# 12929  ACSSF   2010e5     pa      000     0001  0024637         NaN
# 12930  ACSSF   2010e5     pa      000     0001  0024638         NaN
# 12931  ACSSF   2010e5     pa      000     0001  0024639         NaN
# 12932  ACSSF   2010e5     pa      000     0001  0024640         NaN
# 12933  ACSSF   2010e5     pa      000     0001  0024641         NaN
# 12934  ACSSF   2010e5     pa      000     0001  0024642         NaN
# 12935  ACSSF   2010e5     pa      000     0001  0024643         NaN
# 12936  ACSSF   2010e5     pa      000     0001  0024644         NaN
# 12937  ACSSF   2010e5     pa      000     0001  0024645         NaN
# 12938  ACSSF   2010e5     pa      000     0001  0024646         NaN
# 12939  ACSSF   2010e5     pa      000     0001  0024647         NaN
# 12940  ACSSF   2010e5     pa      000     0001  0024648         NaN
# 12941  ACSSF   2010e5     pa      000     0001  0024649         NaN
# 12942  ACSSF   2010e5     pa      000     0001  0024650         NaN
# 12943  ACSSF   2010e5     pa      000     0001  0024651         NaN
# 12944  ACSSF   2010e5     pa      000     0001  0024652         NaN
# 12945  ACSSF   2010e5     pa      000     0001  0024653         NaN
# 12946  ACSSF   2010e5     pa      000     0001  0024654         NaN
# 12947  ACSSF   2010e5     pa      000     0001  0024655         NaN
# 12948  ACSSF   2010e5     pa      000     0001  0024656         NaN
# 12949  ACSSF   2010e5     pa      000     0001  0024657         NaN
# 12950  ACSSF   2010e5     pa      000     0001  0024658         NaN
# 12951  ACSSF   2010e5     pa      000     0001  0024659         NaN
# 12952  ACSSF   2010e5     pa      000     0001  0024660         NaN
# 12953  ACSSF   2010e5     pa      000     0001  0024661         NaN
# 12954  ACSSF   2010e5     pa      000     0001  0024662         NaN
# 12955  ACSSF   2010e5     pa      000     0001  0024663         NaN
# 12956  ACSSF   2010e5     pa      000     0001  0024664         NaN
# 12957  ACSSF   2010e5     pa      000     0001  0024665         NaN
#
#        B07401_002  B07401_003  B07401_004     ...      B07409_021  B07409_022  \
# 0             NaN         NaN         NaN     ...             NaN         NaN
# 1             NaN         NaN         NaN     ...             NaN         NaN
# 2             NaN         NaN         NaN     ...             NaN         NaN
# 3             NaN         NaN         NaN     ...             NaN         NaN
# 4             NaN         NaN         NaN     ...             NaN         NaN
# 5             NaN         NaN         NaN     ...             NaN         NaN
# 6             NaN         NaN         NaN     ...             NaN         NaN
# 7             NaN         NaN         NaN     ...             NaN         NaN
# 8             NaN         NaN         NaN     ...             NaN         NaN
# 9             NaN         NaN         NaN     ...             NaN         NaN
# 10            NaN         NaN         NaN     ...             NaN         NaN
# 11            NaN         NaN         NaN     ...             NaN         NaN
# 12            NaN         NaN         NaN     ...             NaN         NaN
# 13            NaN         NaN         NaN     ...             NaN         NaN
# 14            NaN         NaN         NaN     ...             NaN         NaN
# 15            NaN         NaN         NaN     ...             NaN         NaN
# 16            NaN         NaN         NaN     ...             NaN         NaN
# 17            NaN         NaN         NaN     ...             NaN         NaN
# 18            NaN         NaN         NaN     ...             NaN         NaN
# 19            NaN         NaN         NaN     ...             NaN         NaN
# 20            NaN         NaN         NaN     ...             NaN         NaN
# 21            NaN         NaN         NaN     ...             NaN         NaN
# 22            NaN         NaN         NaN     ...             NaN         NaN
# 23            NaN         NaN         NaN     ...             NaN         NaN
# 24            NaN         NaN         NaN     ...             NaN         NaN
# 25            NaN         NaN         NaN     ...             NaN         NaN
# 26            NaN         NaN         NaN     ...             NaN         NaN
# 27            NaN         NaN         NaN     ...             NaN         NaN
# 28            NaN         NaN         NaN     ...             NaN         NaN
# 29            NaN         NaN         NaN     ...             NaN         NaN
# ...           ...         ...         ...     ...             ...         ...
# 12928         NaN         NaN         NaN     ...             NaN         NaN
# 12929         NaN         NaN         NaN     ...             NaN         NaN
# 12930         NaN         NaN         NaN     ...             NaN         NaN
# 12931         NaN         NaN         NaN     ...             NaN         NaN
# 12932         NaN         NaN         NaN     ...             NaN         NaN
# 12933         NaN         NaN         NaN     ...             NaN         NaN
# 12934         NaN         NaN         NaN     ...             NaN         NaN
# 12935         NaN         NaN         NaN     ...             NaN         NaN
# 12936         NaN         NaN         NaN     ...             NaN         NaN
# 12937         NaN         NaN         NaN     ...             NaN         NaN
# 12938         NaN         NaN         NaN     ...             NaN         NaN
# 12939         NaN         NaN         NaN     ...             NaN         NaN
# 12940         NaN         NaN         NaN     ...             NaN         NaN
# 12941         NaN         NaN         NaN     ...             NaN         NaN
# 12942         NaN         NaN         NaN     ...             NaN         NaN
# 12943         NaN         NaN         NaN     ...             NaN         NaN
# 12944         NaN         NaN         NaN     ...             NaN         NaN
# 12945         NaN         NaN         NaN     ...             NaN         NaN
# 12946         NaN         NaN         NaN     ...             NaN         NaN
# 12947         NaN         NaN         NaN     ...             NaN         NaN
# 12948         NaN         NaN         NaN     ...             NaN         NaN
# 12949         NaN         NaN         NaN     ...             NaN         NaN
# 12950         NaN         NaN         NaN     ...             NaN         NaN
# 12951         NaN         NaN         NaN     ...             NaN         NaN
# 12952         NaN         NaN         NaN     ...             NaN         NaN
# 12953         NaN         NaN         NaN     ...             NaN         NaN
# 12954         NaN         NaN         NaN     ...             NaN         NaN
# 12955         NaN         NaN         NaN     ...             NaN         NaN
# 12956         NaN         NaN         NaN     ...             NaN         NaN
# 12957         NaN         NaN         NaN     ...             NaN         NaN
#
#        B07409_023  B07409_024  B07409_025  B07409_026  B07409_027  B07409_028  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# 5             NaN         NaN         NaN         NaN         NaN         NaN
# 6             NaN         NaN         NaN         NaN         NaN         NaN
# 7             NaN         NaN         NaN         NaN         NaN         NaN
# 8             NaN         NaN         NaN         NaN         NaN         NaN
# 9             NaN         NaN         NaN         NaN         NaN         NaN
# 10            NaN         NaN         NaN         NaN         NaN         NaN
# 11            NaN         NaN         NaN         NaN         NaN         NaN
# 12            NaN         NaN         NaN         NaN         NaN         NaN
# 13            NaN         NaN         NaN         NaN         NaN         NaN
# 14            NaN         NaN         NaN         NaN         NaN         NaN
# 15            NaN         NaN         NaN         NaN         NaN         NaN
# 16            NaN         NaN         NaN         NaN         NaN         NaN
# 17            NaN         NaN         NaN         NaN         NaN         NaN
# 18            NaN         NaN         NaN         NaN         NaN         NaN
# 19            NaN         NaN         NaN         NaN         NaN         NaN
# 20            NaN         NaN         NaN         NaN         NaN         NaN
# 21            NaN         NaN         NaN         NaN         NaN         NaN
# 22            NaN         NaN         NaN         NaN         NaN         NaN
# 23            NaN         NaN         NaN         NaN         NaN         NaN
# 24            NaN         NaN         NaN         NaN         NaN         NaN
# 25            NaN         NaN         NaN         NaN         NaN         NaN
# 26            NaN         NaN         NaN         NaN         NaN         NaN
# 27            NaN         NaN         NaN         NaN         NaN         NaN
# 28            NaN         NaN         NaN         NaN         NaN         NaN
# 29            NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 12928         NaN         NaN         NaN         NaN         NaN         NaN
# 12929         NaN         NaN         NaN         NaN         NaN         NaN
# 12930         NaN         NaN         NaN         NaN         NaN         NaN
# 12931         NaN         NaN         NaN         NaN         NaN         NaN
# 12932         NaN         NaN         NaN         NaN         NaN         NaN
# 12933         NaN         NaN         NaN         NaN         NaN         NaN
# 12934         NaN         NaN         NaN         NaN         NaN         NaN
# 12935         NaN         NaN         NaN         NaN         NaN         NaN
# 12936         NaN         NaN         NaN         NaN         NaN         NaN
# 12937         NaN         NaN         NaN         NaN         NaN         NaN
# 12938         NaN         NaN         NaN         NaN         NaN         NaN
# 12939         NaN         NaN         NaN         NaN         NaN         NaN
# 12940         NaN         NaN         NaN         NaN         NaN         NaN
# 12941         NaN         NaN         NaN         NaN         NaN         NaN
# 12942         NaN         NaN         NaN         NaN         NaN         NaN
# 12943         NaN         NaN         NaN         NaN         NaN         NaN
# 12944         NaN         NaN         NaN         NaN         NaN         NaN
# 12945         NaN         NaN         NaN         NaN         NaN         NaN
# 12946         NaN         NaN         NaN         NaN         NaN         NaN
# 12947         NaN         NaN         NaN         NaN         NaN         NaN
# 12948         NaN         NaN         NaN         NaN         NaN         NaN
# 12949         NaN         NaN         NaN         NaN         NaN         NaN
# 12950         NaN         NaN         NaN         NaN         NaN         NaN
# 12951         NaN         NaN         NaN         NaN         NaN         NaN
# 12952         NaN         NaN         NaN         NaN         NaN         NaN
# 12953         NaN         NaN         NaN         NaN         NaN         NaN
# 12954         NaN         NaN         NaN         NaN         NaN         NaN
# 12955         NaN         NaN         NaN         NaN         NaN         NaN
# 12956         NaN         NaN         NaN         NaN         NaN         NaN
# 12957         NaN         NaN         NaN         NaN         NaN         NaN
#
#        B07409_029  B07409_030
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# 5             NaN         NaN
# 6             NaN         NaN
# 7             NaN         NaN
# 8             NaN         NaN
# 9             NaN         NaN
# 10            NaN         NaN
# 11            NaN         NaN
# 12            NaN         NaN
# 13            NaN         NaN
# 14            NaN         NaN
# 15            NaN         NaN
# 16            NaN         NaN
# 17            NaN         NaN
# 18            NaN         NaN
# 19            NaN         NaN
# 20            NaN         NaN
# 21            NaN         NaN
# 22            NaN         NaN
# 23            NaN         NaN
# 24            NaN         NaN
# 25            NaN         NaN
# 26            NaN         NaN
# 27            NaN         NaN
# 28            NaN         NaN
# 29            NaN         NaN
# ...           ...         ...
# 12928         NaN         NaN
# 12929         NaN         NaN
# 12930         NaN         NaN
# 12931         NaN         NaN
# 12932         NaN         NaN
# 12933         NaN         NaN
# 12934         NaN         NaN
# 12935         NaN         NaN
# 12936         NaN         NaN
# 12937         NaN         NaN
# 12938         NaN         NaN
# 12939         NaN         NaN
# 12940         NaN         NaN
# 12941         NaN         NaN
# 12942         NaN         NaN
# 12943         NaN         NaN
# 12944         NaN         NaN
# 12945         NaN         NaN
# 12946         NaN         NaN
# 12947         NaN         NaN
# 12948         NaN         NaN
# 12949         NaN         NaN
# 12950         NaN         NaN
# 12951         NaN         NaN
# 12952         NaN         NaN
# 12953         NaN         NaN
# 12954         NaN         NaN
# 12955         NaN         NaN
# 12956         NaN         NaN
# 12957         NaN         NaN
#
# [12958 rows x 236 columns]

# %% [markdown]
# ## Write ACSYYYY 5-year description.html

# %%
# Check if dataset is already defined.  If not, define it as a map, otherwise, leave it alone
try:
  dataset
except NameError:
  dataset = {}

column_dir = 'columncache'

def write_acs_5year_description(year, force_regenerate=False):
    dataset[year] = 'acs{year}_5year_tract2010'.format(**locals())
    description_path = column_dir + '/' + dataset[year] + '/description.html'

    if os.path.exists(description_path) and not force_regenerate:
        print '{description_path} already exists, skipping'.format(**locals())
        return

    table_rows = []

    for seqno in range(1, 1000):
        template = read_acs_5year_template(year, seqno)
        if template is None:
            break
        for col in range(6, template.shape[1]):
            colname = template.columns.values[col]
            description = template.iloc[0,col]
            try:
                description = description.replace(':', '')
                description = re.sub(r'\s*%\s*', ' &mdash; ', description)
            except:
                print "%d:%d col %d description = '%s', using '%s' instead" % (year, seqno, col, description,colname)
                description = colname
            # format can't handle array reference, so put dataset[year] in a flat variable for the format to work
            dataset_var = dataset[year]
            table_rows.append(u'<tr><td>{dataset_var}.{colname}</td><td>{description}</td></tr>\n'.format(**locals()))

    html = '<table>' + ''.join(table_rows) + '</table>'

    try:
        os.makedirs(os.path.dirname(description_path))
    except:
        pass
    open(description_path, 'w').write(html.encode('utf8'))
    print 'Wrote %d column names and descriptions to %s' % (len(table_rows), description_path)
    print 'Check it out at http://dotmaptiles.createlab.org/data/acs{year}_5year_tract2010'.format(**locals())

# %%
write_acs_5year_description(process_year)
# Out:
# Wrote 21487 column names and descriptions to columncache/acs2010_5year_tract2010/description.html
# Check it out at http://dotmaptiles.createlab.org/data/acs2010_5year_tract2010

# %% [markdown]
# ## Create ACS2015 block-level population

# %% [markdown]
# ### Read 2010 block geoids and 2010 block populations

# %%
block_populations = numpy.load('columncache/census2010_block2010/p001001.numpy')
print 'block_populations has', sum(block_populations), 'total people'
# Out:
# block_populations has 308745538 total people

# %%
# block_geoids_2010 = [row[0] for row in query_psql("SELECT geoid2010 FROM sf1_2010_block_p001 order by blockidx2010")]
block_geoids_2010 = json.load(open('block_geoids_2010.json'))
print 'There are', len(block_geoids_2010), 'blocks'

assert(len(block_geoids_2010) + 1 == len(block_populations))
# Out:
# There are 11078297 blocks

# %% [markdown]
# ### Compute 2010 population by tract and block indices from tract

# %%
tract_populations = {}
tract_block_indexes = {}

for block_index_minus_one, block_geoid in enumerate(block_geoids_2010):
    block_index = block_index_minus_one + 1
    tract_name = block_geoid[0:11] # SSCCCTTTTTT
    if tract_name not in tract_populations:
        tract_populations[tract_name] = 0
        tract_block_indexes[tract_name] = []
    tract_populations[tract_name] += block_populations[block_index]
    tract_block_indexes[tract_name].append(block_index)

print 'There are', len(tract_populations), 'tracts'
print 'tract_populations has', sum(tract_populations.values()), 'people'
# Out:
# There are 73057 tracts
# tract_populations has 308745538 people

# %% [markdown]
# ### Map tract identifiers to LOGRECNO using geography file

# %%
tract_to_logrecno_year=None
tract_to_logrecno = {}

def compute_tract_to_logrecno(state, year):
    global tract_to_logrecno_year
    tract_to_logrecno_year=year
    for template in ["capture/ACS{year}_5year/{year}_ACS_Geography_Files/g{year}5{state}.csv",
                     "capture/ACS{year}_5year/{year}_ACS_Geography_Files/geo/g{year}5{state}.csv",
                     "capture/ACS{year}_5year/{year}_ACS_Geography_Files/tab4/sumfile/prod/2009thru2013/geo/g{year}5{state}.csv",
                     "capture/ACS{year}_5year/{year}_ACS_Geography_Files/geog/g{year}5{state}.csv"]:
        csv_path = template.format(**locals())
        if os.path.exists(csv_path):
            geography = pandas.read_csv(csv_path,
                                        dtype=numpy.str,
                                        index_col=False,
                                        header=None,
                                        keep_default_na=False,
                                        na_values=[])

            nrows = geography.shape[0]
            print 'State {state} has {nrows} geography rows'.format(**locals())
    
            ntracts = 0
            tract_to_logrecno[state] = {}
    
            for r in range(0, geography.shape[0]):
                aggregation_level = geography.iloc[r, 2]
                if aggregation_level == '140': # census tract
                    tract_identifier = geography.iloc[r, 48][7:]
                    logrecno = geography.iloc[r, 4]
                    tract_to_logrecno[state][tract_identifier] = logrecno
    
            print 'Found %d tracts for state %s in year %d' % (len(tract_to_logrecno[state]), state, year)
            return

    print '{csv_path} missing, call download_geography_data({year}), skipping {state},{year}'.format(**locals())

# %%
for state in state_names:
    compute_tract_to_logrecno(state, process_year)
# Out:
# State ak has 4193 geography rows
# Found 167 tracts for state ak in year 2010
# State al has 11466 geography rows
# Found 1181 tracts for state al in year 2010
# State ar has 12182 geography rows
# Found 686 tracts for state ar in year 2010
# State az has 11173 geography rows
# Found 1526 tracts for state az in year 2010
# State ca has 52857 geography rows
# Found 8057 tracts for state ca in year 2010
# State co has 10108 geography rows
# Found 1249 tracts for state co in year 2010
# State ct has 6401 geography rows
# Found 833 tracts for state ct in year 2010
# State dc has 857 geography rows
# Found 179 tracts for state dc in year 2010
# State de has 1714 geography rows
# Found 218 tracts for state de in year 2010
# State fl has 28273 geography rows
# Found 4245 tracts for state fl in year 2010
# State ga has 16360 geography rows
# Found 1969 tracts for state ga in year 2010
# State hi has 3120 geography rows
# Found 351 tracts for state hi in year 2010
# State ia has 16074 geography rows
# Found 825 tracts for state ia in year 2010
# State id has 3694 geography rows
# Found 298 tracts for state id in year 2010
# State il has 33251 geography rows
# Found 3123 tracts for state il in year 2010
# State in has 16555 geography rows
# Found 1511 tracts for state in in year 2010
# State ks has 12884 geography rows
# Found 770 tracts for state ks in year 2010
# State ky has 10596 geography rows
# Found 1115 tracts for state ky in year 2010
# State la has 12587 geography rows
# Found 1148 tracts for state la in year 2010
# State ma has 11869 geography rows
# Found 1478 tracts for state ma in year 2010
# State md has 11272 geography rows
# Found 1406 tracts for state md in year 2010
# State me has 4999 geography rows
# Found 358 tracts for state me in year 2010
# State mi has 23401 geography rows
# Found 2813 tracts for state mi in year 2010
# State mn has 19659 geography rows
# Found 1338 tracts for state mn in year 2010
# State mo has 19801 geography rows
# Found 1393 tracts for state mo in year 2010
# State ms has 9187 geography rows
# Found 664 tracts for state ms in year 2010
# State mt has 4714 geography rows
# Found 271 tracts for state mt in year 2010
# State nc has 21777 geography rows
# Found 2195 tracts for state nc in year 2010
# State nd has 8092 geography rows
# Found 205 tracts for state nd in year 2010
# State ne has 9796 geography rows
# Found 532 tracts for state ne in year 2010
# State nh has 3568 geography rows
# Found 295 tracts for state nh in year 2010
# State nj has 14388 geography rows
# Found 2010 tracts for state nj in year 2010
# State nm has 5991 geography rows
# Found 499 tracts for state nm in year 2010
# State nv has 4695 geography rows
# Found 687 tracts for state nv in year 2010
# State ny has 34946 geography rows
# Found 4919 tracts for state ny in year 2010
# State oh has 28188 geography rows
# Found 2952 tracts for state oh in year 2010
# State ok has 11933 geography rows
# Found 1046 tracts for state ok in year 2010
# State or has 7807 geography rows
# Found 834 tracts for state or in year 2010
# State pa has 29951 geography rows
# Found 3218 tracts for state pa in year 2010
# State ri has 1972 geography rows
# Found 244 tracts for state ri in year 2010
# State sc has 9356 geography rows
# Found 1103 tracts for state sc in year 2010
# State sd has 7045 geography rows
# Found 222 tracts for state sd in year 2010
# State tn has 15296 geography rows
# Found 1497 tracts for state tn in year 2010
# State tx has 42248 geography rows
# Found 5265 tracts for state tx in year 2010
# State ut has 5563 geography rows
# Found 588 tracts for state ut in year 2010
# State va has 15731 geography rows
# Found 1907 tracts for state va in year 2010
# State vt has 2856 geography rows
# Found 184 tracts for state vt in year 2010
# State wa has 12985 geography rows
# Found 1458 tracts for state wa in year 2010
# State wi has 18050 geography rows
# Found 1409 tracts for state wi in year 2010
# State wv has 6351 geography rows
# Found 484 tracts for state wv in year 2010
# State wy has 2214 geography rows
# Found 132 tracts for state wy in year 2010

# %% [markdown]
# ### Interpolate and write columns for data file

# %%
# AW 2/15/18: Randy believes this version is older than the one below.  I discovered this after putting in some work to generalize it to a 
# parameterized year.  The current version doesn't work.
# TODO: can we do this with a data frame then write out columns?

# def interpolate_acs_file(year, state, seq):
#     print 'Reading %s:%d for %d' % (state, seq, year)
#     data = read_acs_5year_data(year, state, seq)

#     print 'Mapping locrecno to row'
#     logrecnos = data['LOGRECNO']

#     logrecno_to_row = {}

#     for r, logrecno in enumerate(logrecnos):
#         logrecno_to_row[logrecno] = r
    
#     col_names = data.columns.values[6:]
#     print 'Iterating across %d columns' % len(col_names)
#     for col_name in col_names:
#         input_col = data[col_name]
#         output_col_path = column_dir + '/' + dataset + '/' + col_name + '.float32'
#         if os.path.exists(output_col_path):
#             print '%s already exists, skipping' % output_col_path
#             continue

#         output_col = numpy.zeros(block_populations.size, dtype=numpy.float32)

#         for tract in sorted(tract_to_logrecno[state].keys()):
#             input_pop = input_col[logrecno_to_row[tract_to_logrecno[state][tract]]]
#             if not isinstance(input_pop, numbers.Number):
#                 if input_pop == '.':
#                     input_pop = 0
#                 else:
#                     try:
#                         input_pop = float(input_pop)
#                     except:
#                         print 'That population is'
#                         print input_pop
#                         print type(input_pop)
#                         print '>%s<' % input_pop
#                         input_pop = 0
#             if not tract in tract_block_indexes:
#                 print 'missing tract {tract} from tract_block_indexes'.format(**locals())
#             else:
#                 for block_index in tract_block_indexes[tract]:
#                     if block_populations[block_index]:
#                         output_col[block_index] = input_pop * float(block_populations[block_index]) / tract_populations[tract]
            
#         output_col.tofile(output_col_path + '.tmp')
#         os.rename(output_col_path + '.tmp', output_col_path)
#         print 'Created %s' % output_col_path

# for seq in range(97, 2000):
#     interpolate_acs_file(year, 'pa', seq)

# %%
# TODO: can we do this with a data frame then write out columns?

def interpolate_acs_file(year, seq):
    global tract_to_logrecno_year
    sys.stdout.write("interpolating %d:%d\n" % (year, seq))
    
   # Make sure dataset[year] already exists.  If not, prompt to run write_acs_5year_description(year)
    try:
        dataset[year]
    except:
        print "dataset[%d] not defined.  Call write_acs_5year_description(%d) first." % (year, year)
        return None


    # Make sure tract_to_logrecno_year already exists and matches year.  If not, prompt to run compute_tract_to_logrecno(state, %d)
    try:
        tract_to_logrecno_year
    except:
        print "tract_to_logrecno_year not defined.  Call compute_tract_to_logrecno(state, %d) first." % (year)
        return None

    if tract_to_logrecno_year != year:
        print "tract_to_logrecno_year doesn't match.  Call compute_tract_to_logrecno(state, %d) first." % (year)
        return None
    
    output_cols = {}
    missing_tracts = {}
    num_nans=0
    for state in state_names:
        data = read_acs_5year_data(year, state, seq)
    
        logrecnos = data['LOGRECNO']

        logrecno_to_row = {}

        col_names = data.columns.values[6:]
        sys.stdout.write('%s:%d %d has %d columns\n' % (state, seq, year, len(col_names)))
        assert len(col_names) < 500   # sanity check to avoid demanding too much RAM on hal15

        if state == state_names[0]:
            missing = 0
            # First state.  Now that we know the col names, let's see if the output files all already exist
            for col_name in col_names:
                output_col_path = column_dir + '/' + dataset[year] + '/' + col_name + '.float32'
                if not os.path.exists(output_col_path):
                    missing += 1
            if missing == 0:
                sys.stdout.write("All %d columns for sequence %d already exist, skipping\n" % (len(col_names), seq))
                return
        
        for r, logrecno in enumerate(logrecnos):
            logrecno_to_row[logrecno] = r
    
        for col_name in col_names:
            input_col = data[col_name]
                
            if not col_name in output_cols:
                output_cols[col_name] = numpy.zeros(block_populations.size, dtype=numpy.float32)
            output_col = output_cols[col_name]

            for tract in sorted(tract_to_logrecno[state].keys()):
                input_pop = input_col[logrecno_to_row[tract_to_logrecno[state][tract]]]
                if not isinstance(input_pop, numbers.Number):
                    if input_pop == '.':
                        input_pop = 0
                    else:
                        try:
                            input_pop = float(input_pop)
                        except:
                            print 'That population is'
                            print input_pop
                            print type(input_pop)
                            print '>%s<' % input_pop
                            input_pop = 0
                            
                if math.isnan(input_pop):
                    #sys.stdout.write('Warning, %s:%d Tract %s is nan\n' % (state, seq, tract))
                    num_nans=num_nans+1

                if not tract in tract_block_indexes:
                    missing_tracts[tract] = True
                else:
                    for block_index in tract_block_indexes[tract]:
                        if block_populations[block_index]:
                            output_col[block_index] = input_pop * float(block_populations[block_index]) / tract_populations[tract]
            
    sys.stdout.write('Seq %d missing tracts: %s\n' % (seq, sorted(missing_tracts.keys())))
        
    if num_nans>0:
        sys.stdout.write('Seq %d contains %d nans' % (seq,num_nans))
        
    for col_name in sorted(output_cols.keys()):
        output_col_path = column_dir + '/' + dataset[year] + '/' + col_name + '.float32'
        output_cols[col_name].tofile(output_col_path + '.tmp')
        os.rename(output_col_path + '.tmp', output_col_path)
        sys.stdout.write('Created %s with sum %f\n' % (output_col_path, output_cols[col_name].sum()))

# %%
interpolate_acs_file(process_year, 1)
# Out:
# interpolating 2010:1
# ak:1 2010 has 230 columns
# al:1 2010 has 230 columns
# ar:1 2010 has 230 columns
# az:1 2010 has 230 columns
# ca:1 2010 has 230 columns
# co:1 2010 has 230 columns
# ct:1 2010 has 230 columns
# dc:1 2010 has 230 columns
# de:1 2010 has 230 columns
# fl:1 2010 has 230 columns
# ga:1 2010 has 230 columns
# hi:1 2010 has 230 columns
# ia:1 2010 has 230 columns
# id:1 2010 has 230 columns
# il:1 2010 has 230 columns
# in:1 2010 has 230 columns
# ks:1 2010 has 230 columns
# ky:1 2010 has 230 columns
# la:1 2010 has 230 columns
# ma:1 2010 has 230 columns
# md:1 2010 has 230 columns
# me:1 2010 has 230 columns
# mi:1 2010 has 230 columns
# mn:1 2010 has 230 columns
# mo:1 2010 has 230 columns
# ms:1 2010 has 230 columns
# mt:1 2010 has 230 columns
# nc:1 2010 has 230 columns
# nd:1 2010 has 230 columns
# ne:1 2010 has 230 columns
# nh:1 2010 has 230 columns
# nj:1 2010 has 230 columns
# nm:1 2010 has 230 columns
# nv:1 2010 has 230 columns
# ny:1 2010 has 230 columns
# oh:1 2010 has 230 columns
# ok:1 2010 has 230 columns
# or:1 2010 has 230 columns
# pa:1 2010 has 230 columns
# ri:1 2010 has 230 columns
# sc:1 2010 has 230 columns
# sd:1 2010 has 230 columns
# tn:1 2010 has 230 columns
# tx:1 2010 has 230 columns
# ut:1 2010 has 230 columns
# va:1 2010 has 230 columns
# vt:1 2010 has 230 columns
# wa:1 2010 has 230 columns
# wi:1 2010 has 230 columns
# wv:1 2010 has 230 columns
# wy:1 2010 has 230 columns
# Seq 1 missing tracts: []
# Seq 1 contains 16803110 nansCreated columncache/acs2010_5year_tract2010/B07401_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_006.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_007.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_008.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_009.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_010.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_011.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_012.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_013.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_014.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_015.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_016.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_017.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_018.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_019.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_020.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_021.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_022.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_023.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_024.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_025.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_026.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_027.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_028.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_029.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_030.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_031.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_032.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_033.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_034.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_035.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_036.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_037.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_038.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_039.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_040.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_041.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_042.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_043.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_044.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_045.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_046.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_047.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_048.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_049.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_050.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_051.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_052.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_053.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_054.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_055.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_056.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_057.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_058.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_059.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_060.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_061.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_062.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_063.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_064.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_065.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_066.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_067.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_068.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_069.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_070.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_071.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_072.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_073.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_074.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_075.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_076.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_077.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_078.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_079.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07401_080.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07402_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07402_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07402_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07402_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07402_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_006.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_007.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_008.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_009.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_010.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_011.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_012.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_013.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_014.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07403_015.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404A_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404A_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404A_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404A_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404A_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404B_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404B_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404B_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404B_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404B_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404C_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404C_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404C_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404C_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404C_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404D_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404D_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404D_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404D_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404D_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404E_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404E_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404E_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404E_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404E_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404F_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404F_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404F_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404F_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404F_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404G_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404G_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404G_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404G_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404G_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404H_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404H_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404H_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404H_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404H_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404I_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404I_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404I_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404I_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07404I_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_006.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_007.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_008.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_009.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_010.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_011.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_012.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_013.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_014.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_015.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_016.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_017.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_018.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_019.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_020.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_021.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_022.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_023.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_024.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07407_025.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_006.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_007.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_008.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_009.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_010.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_011.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_012.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_013.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_014.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_015.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_016.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_017.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_018.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_019.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_020.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_021.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_022.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_023.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_024.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_025.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_026.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_027.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_028.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_029.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07408_030.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_001.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_002.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_003.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_004.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_005.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_006.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_007.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_008.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_009.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_010.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_011.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_012.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_013.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_014.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_015.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_016.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_017.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_018.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_019.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_020.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_021.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_022.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_023.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_024.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_025.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_026.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_027.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_028.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_029.float32 with sum nan
# Created columncache/acs2010_5year_tract2010/B07409_030.float32 with sum nan

# %%
# 4 seems conservative on a 64GB machine
pool = SimpleProcessPoolExecutor(4)

for seq in range(1, 1000):
    pool.submit(interpolate_acs_file, process_year, seq)

pool.shutdown()
None
# Out:
# interpolating 2010:1
# interpolating 2010:3
# interpolating 2010:2
# interpolating 2010:4
# ak:1 2010 has 230 columns
# All 230 columns for sequence 1 already exist, skipping
# ak:3 2010 has 237 columns
# interpolating 2010:5
# ak:5 2010 has 175 columns
# ak:2 2010 has 95 columns
# ak:4 2010 has 217 columns
# al:2 2010 has 95 columns
# al:5 2010 has 175 columns
# al:4 2010 has 217 columns
# al:3 2010 has 237 columns
# ar:2 2010 has 95 columns
# az:2 2010 has 95 columns

# %%
year
# Out:
# 2016

# %%
data = read_acs_5year_data(2015, 'ak', 1)
# Out:
# Checking for capture/ACS2015_5year/group2/e20155ak0001000.txt

# %%
logrecnos = data['LOGRECNO']

# %%
tract_to_logrecno['ak']['02198000300']
# Out:
# '0000617'

# %%
for i in range(0,len(logrecnos)):
    if(logrecnos[i]=='0000617'):
        print i
# Out:
# 151

# %%
col_names = data.columns.values[6:]
col_names
# Out:
# array([u'B00001_001', u'B00002_001'], dtype=object)

# %%
len(tract_block_indexes.keys())

# %%
# !ls -l columncache/acs2015_5year_tract2010/B08006_002.float32

# %%
x=numpy.memmap('columncache/acs2015_5year_tract2010/B00001_001.float32', dtype=numpy.float32, mode='r')

# %%
x.sum()
# Out:
# memmap(nan, dtype=float32)

# %%
x
# Out:
# memmap([ 0.        ,  7.81642246,  0.        , ...,  1.24807394,
#         0.        ,  0.        ], dtype=float32)
